# %% [markdown]
# <a href="https://colab.research.google.com/github/thereaper01/smarkz01/blob/master/LDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LDA - Topic Modelling**
#
# ---

# %%
#Paramters():
#inputs: Document term matrix, (bow or tfidf)
#no_of_topics we want
#no of epocs we want

# %% [markdown]
# **What it does?**
#
# ---
#
#
# It learns the topic mix in each word and the word mix in each topic
# The output is the the distribution of words in each topic seperated

# %% [markdown]
# Lets say we the model A 100 topics.
# Set the number of topics as (K=2).
# Then the model randomly assigns the words to any of the topic.
# Then it goes through each word and checks how many times it occurs in each TOPIC and reassigns unit our number of epocs are reached.

# %% [markdown]
# 1)Checks how often topic appears in doc.
# 2)Checks how often words occur in topic

# %%
import gensim

import nltk
import wikipedia as w

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
dora=w.page("Doraemon")
kgp=w.page("IIT Kharagpur")
baski=w.page("Basketball")
covid=w.page("Coronavirus disease 2019")

# %%
corpus=[dora.content,kgp.content,data.content,covid.content]
len(corpus)
# Out:
# 4

# %%
import re

from bs4 import BeautifulSoup

from nltk.stem import LancasterStemmer, WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
  

lemma=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocess(doc):
  doc=re.sub(r'\W', ' ',str(doc))
  doc = doc.lower()                 # Converting to lowercase
  cleanr = re.compile('<.*?>')
  doc = re.sub(cleanr, ' ',str(doc))        #Removing HTML tags
  doc = re.sub(r'[?|!|\'|"|#]',r'',str(doc))
  doc = re.sub(r'[.|,|)|(|\|/]',r' ',str(doc))
  doc=re.sub(r'\s+', ' ',str(doc),flags=re.I)
  doc=re.sub(r'^b\s+', ' ',str(doc))
  doc = re.sub(r'\[[0-9]*\]', ' ', doc)
  doc = re.sub(r'\s+', ' ',doc)
  # Removing special characters and digits
  doc = re.sub('[^a-zA-Z]', ' ', doc )
  doc = re.sub(r'\s+', ' ', doc)
  doc_list = nltk.sent_tokenize(doc)
  stopwords = nltk.corpus.stopwords.words('english')
  #Lemmatization
  tokens=doc.split()
  tokens=[lemma.lemmatize(word) for word in tokens]
  tokens=[word for word in tokens if word not in stopwords]
  return tokens

processed_data=[]
for text in corpus:
    tokens=preprocess(text)
    processed_data.append(tokens)

# %%
processed_data[0:10]
# Out:
# [['doraemon',
#   'japanese',
#   'aemo',
#   'japanese',
#   'manga',
#   'series',
#   'written',
#   'illustrated',
#   'fujiko',
#   'fujio',
#   'pen',
#   'name',
#   'duo',
#   'hiroshi',
#   'fujimoto',
#   'motoo',
#   'abiko',
#   'series',
#   'ha',
#   'also',
#   'adapted',
#   'successful',
#   'anime',
#   'series',
#   'medium',
#   'franchise',
#   'story',
#   'revolves',
#   'around',
#   'earless',
#   'robotic',
#   'cat',
#   'named',
#   'doraemon',
#   'travel',
#   'back',
#   'time',
#   'nd',
#   'century',
#   'aid',
#   'boy',
#   'named',
#   'nobita',
#   'nobi',
#   'nobi',
#   'nobita',
#   'first',
#   'full',
#   'story',
#   'doraemon',
#   'manga',
#   'series',
#   'wa',
#   'published',
#   'january',
#   'pre',
#   'advertisement',
#   'manga',
#   'wa',
#   'published',
#   'six',
#   'different',
#   'magazine',
#   'december',
#   'total',
#   'story',
#   'created',
#   'original',
#   'series',
#   'published',
#   'shogakukan',
#   'best',
#   'selling',
#   'manga',
#   'child',
#   'one',
#   'best',
#   'selling',
#   'manga',
#   'world',
#   'ha',
#   'sold',
#   'million',
#   'copy',
#   'volume',
#   'collected',
#   'takaoka',
#   'central',
#   'library',
#   'toyama',
#   'japan',
#   'fujiko',
#   'fujio',
#   'wa',
#   'born',
#   'turner',
#   'broadcasting',
#   'system',
#   'bought',
#   'right',
#   'doraemon',
#   'anime',
#   'series',
#   'mid',
#   'english',
#   'language',
#   'release',
#   'united',
#   'state',
#   'cancelled',
#   'without',
#   'explanation',
#   'broadcasting',
#   'episode',
#   'july',
#   'voyager',
#   'japan',
#   'announced',
#   'manga',
#   'would',
#   'released',
#   'digitally',
#   'english',
#   'via',
#   'amazon',
#   'kindle',
#   'e',
#   'book',
#   'service',
#   'award',
#   'doraemon',
#   'include',
#   'japan',
#   'cartoonist',
#   'association',
#   'award',
#   'excellence',
#   'first',
#   'shogakukan',
#   'manga',
#   'award',
#   'child',
#   'manga',
#   'first',
#   'osamu',
#   'tezuka',
#   'culture',
#   'award',
#   'march',
#   'japan',
#   'foreign',
#   'ministry',
#   'appointed',
#   'doraemon',
#   'nation',
#   'first',
#   'anime',
#   'ambassador',
#   'ministry',
#   'spokesperson',
#   'explained',
#   'novel',
#   'decision',
#   'attempt',
#   'help',
#   'people',
#   'country',
#   'understand',
#   'japanese',
#   'anime',
#   'better',
#   'deepen',
#   'interest',
#   'japanese',
#   'culture',
#   'foreign',
#   'ministry',
#   'action',
#   'confirms',
#   'doraemon',
#   'ha',
#   'come',
#   'considered',
#   'japanese',
#   'cultural',
#   'icon',
#   'india',
#   'hindi',
#   'telugu',
#   'tamil',
#   'translation',
#   'ha',
#   'telecasted',
#   'anime',
#   'version',
#   'highest',
#   'rated',
#   'kid',
#   'show',
#   'winning',
#   'best',
#   'show',
#   'kid',
#   'award',
#   'twice',
#   'nickelodeon',
#   'kid',
#   'choice',
#   'award',
#   'india',
#   'time',
#   'asia',
#   'magazine',
#   'acclaimed',
#   'character',
#   'asian',
#   'hero',
#   'special',
#   'feature',
#   'survey',
#   'edited',
#   'english',
#   'dub',
#   'distributed',
#   'tv',
#   'asahi',
#   'aired',
#   'disney',
#   'xd',
#   'united',
#   'state',
#   'started',
#   'july',
#   'august',
#   'another',
#   'english',
#   'dubbed',
#   'version',
#   'distributed',
#   'luk',
#   'internacional',
#   'began',
#   'broadcasting',
#   'boomerang',
#   'uk',
#   'film',
#   'series',
#   'largest',
#   'number',
#   'admission',
#   'japan',
#   'plot',
#   'doraemon',
#   'cat',
#   'robot',
#   'nd',
#   'century',
#   'sent',
#   'help',
#   'nobita',
#   'nobi',
#   'young',
#   'boy',
#   'score',
#   'poor',
#   'grade',
#   'frequently',
#   'bullied',
#   'two',
#   'classmate',
#   'takeshi',
#   'goda',
#   'nicknamed',
#   'gian',
#   'suneo',
#   'honekawa',
#   'gian',
#   'sidekick',
#   'doraemon',
#   'sent',
#   'take',
#   'care',
#   'nobita',
#   'sewashi',
#   'nobi',
#   'nobita',
#   'future',
#   'grandson',
#   'descendant',
#   'improve',
#   'life',
#   'doraemon',
#   'ha',
#   'four',
#   'dimensional',
#   'pouch',
#   'store',
#   'unexpected',
#   'gadget',
#   'help',
#   'improve',
#   'life',
#   'ha',
#   'many',
#   'gadget',
#   'get',
#   'future',
#   'departmental',
#   'store',
#   'bamboo',
#   'copter',
#   'small',
#   'piece',
#   'headgear',
#   'allow',
#   'user',
#   'fly',
#   'anywhere',
#   'door',
#   'pink',
#   'colored',
#   'door',
#   'allows',
#   'people',
#   'travel',
#   'according',
#   'thought',
#   'person',
#   'turn',
#   'knob',
#   'time',
#   'kerchief',
#   'handkerchief',
#   'turn',
#   'object',
#   'new',
#   'old',
#   'person',
#   'young',
#   'old',
#   'translator',
#   'tool',
#   'cuboid',
#   'jelly',
#   'allow',
#   'people',
#   'converse',
#   'language',
#   'across',
#   'universe',
#   'designer',
#   'camera',
#   'produce',
#   'dress',
#   'many',
#   'nobita',
#   'closest',
#   'friend',
#   'love',
#   'interest',
#   'shizuka',
#   'minamoto',
#   'eventually',
#   'becomes',
#   'wife',
#   'future',
#   'ha',
#   'child',
#   'named',
#   'nobisuke',
#   'nobi',
#   'name',
#   'nobita',
#   'father',
#   'nobita',
#   'often',
#   'bullied',
#   'gian',
#   'suneo',
#   'shown',
#   'friend',
#   'episode',
#   'especially',
#   'movie',
#   'episode',
#   'typical',
#   'story',
#   'consists',
#   'nobita',
#   'taking',
#   'gadget',
#   'doraemon',
#   'need',
#   'eventually',
#   'causing',
#   'trouble',
#   'wa',
#   'trying',
#   'solve',
#   'medium',
#   'manga',
#   'december',
#   'doraemon',
#   'manga',
#   'appeared',
#   'six',
#   'different',
#   'child',
#   'monthly',
#   'magazine',
#   'published',
#   'shogakukan',
#   'magazine',
#   'aimed',
#   'child',
#   'nursery',
#   'school',
#   'fourth',
#   'grade',
#   'corocoro',
#   'comic',
#   'wa',
#   'launched',
#   'flagship',
#   'magazine',
#   'doraemon',
#   'since',
#   'debut',
#   'doraemon',
#   'story',
#   'selectively',
#   'collected',
#   'forty',
#   'five',
#   'tank',
#   'bon',
#   'volume',
#   'published',
#   'shogakukan',
#   'tent',
#   'mushi',
#   'comic',
#   'imprint',
#   'shogakukan',
#   'published',
#   'master',
#   'work',
#   'collection',
#   'consisting',
#   'twenty',
#   'volume',
#   'july',
#   'september',
#   'addition',
#   'doraemon',
#   'ha',
#   'appeared',
#   'variety',
#   'manga',
#   'series',
#   'sh',
#   'gakukan',
#   'sh',
#   'gakukan',
#   'published',
#   'series',
#   'five',
#   'manga',
#   'volume',
#   'title',
#   'doraemon',
#   'doraemon',
#   'plus',
#   'found',
#   'forty',
#   'five',
#   'original',
#   'volume',
#   'december',
#   'sixth',
#   'volume',
#   'doraemon',
#   'plus',
#   'wa',
#   'published',
#   'wa',
#   'first',
#   'volume',
#   'eight',
#   'year',
#   'two',
#   'series',
#   'bilingual',
#   'japanese',
#   'english',
#   'volume',
#   'manga',
#   'shogakukan',
#   'english',
#   'comic',
#   'title',
#   'doraemon',
#   'gadget',
#   'cat',
#   'future',
#   'two',
#   'audio',
#   'version',
#   'first',
#   'series',
#   'ha',
#   'ten',
#   'volume',
#   'second',
#   'six',
#   'addition',
#   'st',
#   'century',
#   'publishing',
#   'house',
#   'released',
#   'bilingual',
#   'english',
#   'chinese',
#   'version',
#   'mainland',
#   'china',
#   'july',
#   'fujiko',
#   'fujio',
#   'production',
#   'announced',
#   'would',
#   'collaborating',
#   'ebook',
#   'publisher',
#   'voyager',
#   'japan',
#   'localization',
#   'company',
#   'altjapan',
#   'co',
#   'ltd',
#   'release',
#   'english',
#   'language',
#   'version',
#   'manga',
#   'full',
#   'color',
#   'digitally',
#   'via',
#   'amazon',
#   'kindle',
#   'platform',
#   'north',
#   'america',
#   'shogakukan',
#   'released',
#   'first',
#   'volume',
#   'november',
#   'english',
#   'version',
#   'incorporates',
#   'variety',
#   'change',
#   'character',
#   'name',
#   'nobita',
#   'noby',
#   'shizuka',
#   'sue',
#   'suneo',
#   'sneech',
#   'gian',
#   'big',
#   'g',
#   'dorayaki',
#   'yummy',
#   'bun',
#   'fudgy',
#   'pudgy',
#   'pie',
#   'total',
#   'volume',
#   'released',
#   'manga',
#   'ha',
#   'published',
#   'english',
#   'print',
#   'shogakukan',
#   'asia',
#   'using',
#   'translation',
#   'manga',
#   'available',
#   'amazon',
#   'kindle',
#   'unlike',
#   'amazon',
#   'kindle',
#   'release',
#   'volume',
#   'black',
#   'white',
#   'instead',
#   'color',
#   'released',
#   'four',
#   'volume',
#   'shogakukan',
#   'started',
#   'digital',
#   'distribution',
#   'forty',
#   'five',
#   'original',
#   'volume',
#   'throughout',
#   'japan',
#   'july',
#   'anime',
#   'brief',
#   'first',
#   'attempt',
#   'animated',
#   'series',
#   'nippon',
#   'television',
#   'doraemon',
#   'remained',
#   'fairly',
#   'exclusive',
#   'manga',
#   'form',
#   'newly',
#   'formed',
#   'animation',
#   'studio',
#   'shin',
#   'ei',
#   'animation',
#   'owned',
#   'tv',
#   'asahi',
#   'produced',
#   'animated',
#   'second',
#   'attempt',
#   'doraemon',
#   'series',
#   'became',
#   'incredibly',
#   'popular',
#   'ended',
#   'episode',
#   'march',
#   'asia',
#   'version',
#   'sometimes',
#   'referred',
#   'yama',
#   'edition',
#   'voice',
#   'actress',
#   'voiced',
#   'doraemon',
#   'series',
#   'celebrating',
#   'anniversary',
#   'franchise',
#   'third',
#   'doraemon',
#   'animated',
#   'series',
#   'began',
#   'airing',
#   'tv',
#   'asahi',
#   'april',
#   'new',
#   'voice',
#   'actor',
#   'staff',
#   'updated',
#   'character',
#   'design',
#   'version',
#   'sometimes',
#   'referred',
#   'asia',
#   'mizuta',
#   'edition',
#   'wasabi',
#   'mizuta',
#   'voice',
#   'actress',
#   'doraemon',
#   'series',
#   'may',
#   'tv',
#   'asahi',
#   'corporation',
#   'announced',
#   'agreement',
#   'walt',
#   'disney',
#   'company',
#   'bring',
#   'series',
#   'disney',
#   'xd',
#   'television',
#   'channel',
#   'united',
#   'state',
#   'beginning',
#   'summer',
#   'year',
#   'besides',
#   'using',
#   'name',
#   'change',
#   'used',
#   'altjapan',
#   'english',
#   'adaptation',
#   'original',
#   'manga',
#   'change',
#   'edits',
#   'also',
#   'made',
#   'make',
#   'show',
#   'relatable',
#   'american',
#   'audience',
#   'japanese',
#   'text',
#   'replaced',
#   'english',
#   'text',
#   'certain',
#   'object',
#   'like',
#   'sign',
#   'graded',
#   'paper',
#   'item',
#   'yen',
#   'note',
#   'replaced',
#   'u',
#   'dollar',
#   'bill',
#   'setting',
#   'changed',
#   'japan',
#   'united',
#   'state',
#   'confirmed',
#   'cast',
#   'member',
#   'new',
#   'american',
#   'adaptation',
#   'include',
#   'veteran',
#   'anime',
#   'voice',
#   'actress',
#   'mona',
#   'marshall',
#   'south',
#   'park',
#   'fame',
#   'title',
#   'role',
#   'doraemon',
#   'johnny',
#   'yong',
#   'bosch',
#   'power',
#   'ranger',
#   'bleach',
#   'fame',
#   'noby',
#   'english',
#   'dub',
#   'produced',
#   'bang',
#   'zoom',
#   'entertainment',
#   'initial',
#   'response',
#   'edited',
#   'dub',
#   'wa',
#   'positive',
#   'disney',
#   'adaptation',
#   'began',
#   'broadcast',
#   'japan',
#   'disney',
#   'channel',
#   'february',
#   'broadcast',
#   'offered',
#   'choice',
#   'english',
#   'voice',
#   'track',
#   'newly',
#   'recorded',
#   'japanese',
#   'track',
#   'japanese',
#   'cast',
#   'series',
#   'emea',
#   'region',
#   'series',
#   'licensed',
#   'luk',
#   'international',
#   'series',
#   'began',
#   'broadcast',
#   'united',
#   'kingdom',
#   'august',
#   'boomerang',
#   'feature',
#   'film',
#   'toho',
#   'released',
#   'first',
#   'series',
#   'annual',
#   'feature',
#   'length',
#   'animated',
#   'film',
#   'based',
#   'lengthy',
#   'special',
#   'volume',
#   'published',
#   'annually',
#   'unlike',
#   'anime',
#   'manga',
#   'based',
#   'story',
#   'select',
#   'volume',
#   'action',
#   'adventure',
#   'oriented',
#   'sh',
#   'nen',
#   'demographic',
#   'taking',
#   'familiar',
#   'character',
#   'doraemon',
#   'placing',
#   'variety',
#   'exotic',
#   'perilous',
#   'setting',
#   'nobita',
#   'friend',
#   'visited',
#   'age',
#   'dinosaur',
#   'far',
#   'reach',
#   'galaxy',
#   'depth',
#   'ocean',
#   'world',
#   'magic',
#   'film',
#   'based',
#   'legend',
#   'atlantis',
#   'literary',
#   'work',
#   'including',
#   'journey',
#   'west',
#   'arabian',
#   'night',
#   'film',
#   'also',
#   'serious',
#   'theme',
#   'especially',
#   'environmental',
#   'topic',
#   'use',
#   'technology',
#   'overall',
#   'film',
#   'somewhat',
#   'darker',
#   'tone',
#   'story',
#   'unlike',
#   'manga',
#   'anime',
#   'video',
#   'game',
#   'japanese',
#   'doraemon',
#   'video',
#   'game',
#   'ranging',
#   'platformer',
#   'game',
#   'rpg',
#   'game',
#   'beginning',
#   'emerson',
#   'arcadia',
#   'system',
#   'doraemon',
#   'also',
#   'seen',
#   'namco',
#   'popular',
#   'taiko',
#   'tatsujin',
#   'rhythm',
#   'game',
#   'series',
#   'like',
#   'taiko',
#   'tatsujin',
#   'metcha',
#   'taiko',
#   'tatsujin',
#   'nanatsu',
#   'shima',
#   'daibouken',
#   'taiko',
#   'tatsujin',
#   'wii',
#   'taiko',
#   'tatsujin',
#   'plus',
#   'taiko',
#   'tatsujin',
#   'dororon',
#   'yokai',
#   'daikessen',
#   'japanese',
#   'version',
#   'microsoft',
#   'movie',
#   'maker',
#   'contained',
#   'doraemon',
#   'themed',
#   'expansion',
#   'pack',
#   'first',
#   'doraemon',
#   'game',
#   'receive',
#   'western',
#   'release',
#   'wa',
#   'doraemon',
#   'story',
#   'season',
#   'musical',
#   'doraemon',
#   'musical',
#   'nobita',
#   'animal',
#   'planet',
#   'butaiban',
#   'doraemon',
#   'nobita',
#   'animaru',
#   'puranetto',
#   'wa',
#   'musical',
#   'based',
#   'anime',
#   'film',
#   'name',
#   'debuted',
#   'tokyo',
#   ...],
#  ['indian',
#   'institute',
#   'technology',
#   'kharagpur',
#   'iit',
#   'kharagpur',
#   'iit',
#   'kgp',
#   'public',
#   'technical',
#   'research',
#   'university',
#   'established',
#   'government',
#   'india',
#   'first',
#   'iits',
#   'established',
#   'recognised',
#   'institute',
#   'national',
#   'importance',
#   'wa',
#   'awarded',
#   'status',
#   'institute',
#   'eminence',
#   'government',
#   'india',
#   'institute',
#   'wa',
#   'initially',
#   'established',
#   'train',
#   'scientist',
#   'engineer',
#   'india',
#   'attained',
#   'independence',
#   'however',
#   'year',
#   'institute',
#   'academic',
#   'capability',
#   'diversified',
#   'offering',
#   'management',
#   'law',
#   'architecture',
#   'humanity',
#   'etc',
#   'iit',
#   'kharagpur',
#   'ha',
#   'square',
#   'kilometre',
#   'acre',
#   'campus',
#   'ha',
#   'resident',
#   'history',
#   'foundation',
#   'committee',
#   'sir',
#   'jogendra',
#   'singh',
#   'member',
#   'viceroy',
#   'executive',
#   'council',
#   'consider',
#   'creation',
#   'higher',
#   'technical',
#   'institution',
#   'post',
#   'world',
#   'war',
#   'ii',
#   'industrial',
#   'development',
#   'india',
#   'wa',
#   'followed',
#   'creation',
#   'member',
#   'committee',
#   'headed',
#   'nalini',
#   'ranjan',
#   'sarkar',
#   'interim',
#   'report',
#   'sarkar',
#   'committee',
#   'recommended',
#   'establishment',
#   'higher',
#   'technical',
#   'institution',
#   'india',
#   'along',
#   'line',
#   'massachusetts',
#   'institute',
#   'technology',
#   'consulting',
#   'university',
#   'illinois',
#   'urbana',
#   'champaign',
#   'along',
#   'affiliated',
#   'secondary',
#   'institution',
#   'report',
#   'urged',
#   'work',
#   'start',
#   'speedy',
#   'establishment',
#   'major',
#   'institution',
#   'four',
#   'quarter',
#   'country',
#   'one',
#   'east',
#   'west',
#   'set',
#   'immediately',
#   'ground',
#   'west',
#   'bengal',
#   'highest',
#   'concentration',
#   'industry',
#   'time',
#   'bidhan',
#   'chandra',
#   'roy',
#   'chief',
#   'minister',
#   'west',
#   'bengal',
#   'persuaded',
#   'jawaharlal',
#   'nehru',
#   'india',
#   'first',
#   'prime',
#   'minister',
#   'establish',
#   'first',
#   'institute',
#   'west',
#   'bengal',
#   'first',
#   'indian',
#   'institute',
#   'technology',
#   'wa',
#   'thus',
#   'established',
#   'may',
#   'eastern',
#   'higher',
#   'technical',
#   'institute',
#   'wa',
#   'located',
#   'esplanade',
#   'east',
#   'calcutta',
#   'september',
#   'shifted',
#   'permanent',
#   'campus',
#   'hijli',
#   'kharagpur',
#   'kilometre',
#   'south',
#   'west',
#   'kolkata',
#   'formerly',
#   'called',
#   'calcutta',
#   'hijli',
#   'used',
#   'detention',
#   'camp',
#   'british',
#   'colonial',
#   'rule',
#   'india',
#   'keep',
#   'indian',
#   'freedom',
#   'fighter',
#   'captive',
#   'iit',
#   'kharagpur',
#   'th',
#   'oldest',
#   'technical',
#   'institute',
#   'west',
#   'bengal',
#   'state',
#   'indian',
#   'institute',
#   'engineering',
#   'science',
#   'technology',
#   'shibpur',
#   'established',
#   'b',
#   'e',
#   'college',
#   'jadavpur',
#   'university',
#   'established',
#   'bengal',
#   'technical',
#   'institute',
#   'rajabazar',
#   'science',
#   'college',
#   'established',
#   'calcutta',
#   'university',
#   'campus',
#   'science',
#   'technology',
#   'first',
#   'session',
#   'started',
#   'august',
#   'student',
#   'teacher',
#   'ten',
#   'department',
#   'institute',
#   'classroom',
#   'laboratory',
#   'administrative',
#   'office',
#   'housed',
#   'historic',
#   'building',
#   'hijli',
#   'detention',
#   'camp',
#   'known',
#   'shaheed',
#   'bhawan',
#   'political',
#   'revolutionary',
#   'imprisoned',
#   'british',
#   'rule',
#   'office',
#   'building',
#   'served',
#   'headquarters',
#   'bomber',
#   'command',
#   'u',
#   'th',
#   'air',
#   'force',
#   'world',
#   'war',
#   'ii',
#   'early',
#   'development',
#   'name',
#   'indian',
#   'institute',
#   'technology',
#   'wa',
#   'adopted',
#   'formal',
#   'inauguration',
#   'institute',
#   'august',
#   'maulana',
#   'abul',
#   'kalam',
#   'azad',
#   'may',
#   'bill',
#   'bill',
#   'wa',
#   'introduced',
#   'lok',
#   'sabha',
#   'declare',
#   'institution',
#   'known',
#   'indian',
#   'institute',
#   'technology',
#   'kharagpur',
#   'institution',
#   'national',
#   'importance',
#   'provide',
#   'incorporation',
#   'matter',
#   'connected',
#   'therewith',
#   'motto',
#   'institute',
#   'taken',
#   'bhagavad',
#   'gita',
#   'chapter',
#   'verse',
#   'ha',
#   'translated',
#   'sri',
#   'aurobindo',
#   'yoga',
#   'skill',
#   'work',
#   'september',
#   'indian',
#   'institute',
#   'technology',
#   'kharagpur',
#   'act',
#   'parliament',
#   'received',
#   'assent',
#   'president',
#   'prime',
#   'minister',
#   'nehru',
#   'first',
#   'convocation',
#   'address',
#   'iit',
#   'kharagpur',
#   'said',
#   'place',
#   'hijli',
#   'detention',
#   'camp',
#   'stand',
#   'fine',
#   'monument',
#   'india',
#   'representing',
#   'india',
#   'urge',
#   'india',
#   'future',
#   'making',
#   'picture',
#   'seems',
#   'symbolical',
#   'change',
#   'coming',
#   'india',
#   'shaheed',
#   'bhawan',
#   'wa',
#   'converted',
#   'museum',
#   'srinivasa',
#   'ramanujan',
#   'complex',
#   'wa',
#   'incorporated',
#   'another',
#   'academic',
#   'complex',
#   'institute',
#   'takshashila',
#   'starting',
#   'operation',
#   'vikramshila',
#   'nalanda',
#   'earlier',
#   'hijli',
#   'detention',
#   'camp',
#   'building',
#   'named',
#   'hijli',
#   'saheed',
#   'bhavan',
#   'nehru',
#   'museum',
#   'science',
#   'technology',
#   'located',
#   'imposing',
#   'building',
#   'bearing',
#   'resemblance',
#   'byzantine',
#   'style',
#   'architecture',
#   'administration',
#   'iit',
#   'kharagpur',
#   'share',
#   'common',
#   'visitor',
#   'position',
#   'held',
#   'president',
#   'india',
#   'iit',
#   'council',
#   'iits',
#   'rest',
#   'iit',
#   'kharagpur',
#   'organisational',
#   'structure',
#   'distinct',
#   'iits',
#   'board',
#   'governor',
#   'iit',
#   'kharagpur',
#   'iit',
#   'council',
#   'ha',
#   'member',
#   'include',
#   'representative',
#   'state',
#   'west',
#   'bengal',
#   'bihar',
#   'jharkhand',
#   'odisha',
#   'addition',
#   'member',
#   'appointed',
#   'iit',
#   'council',
#   'institute',
#   'senate',
#   'board',
#   'governor',
#   'institute',
#   'director',
#   'serf',
#   'chief',
#   'academic',
#   'executive',
#   'officer',
#   'iit',
#   'aided',
#   'deputy',
#   'director',
#   'director',
#   'deputy',
#   'director',
#   'dean',
#   'head',
#   'department',
#   'registrar',
#   'president',
#   'student',
#   'council',
#   'chairman',
#   'hall',
#   'management',
#   'committee',
#   'registrar',
#   'chief',
#   'administrative',
#   'officer',
#   'oversees',
#   'day',
#   'day',
#   'operation',
#   'custodian',
#   'record',
#   'fund',
#   'property',
#   'institute',
#   'charge',
#   'head',
#   'department',
#   'hod',
#   'faculty',
#   'full',
#   'time',
#   'professor',
#   'well',
#   'associate',
#   'assistant',
#   'status',
#   'warden',
#   'hostel',
#   'placed',
#   'chairman',
#   'hall',
#   'management',
#   'committee',
#   'organisation',
#   'iit',
#   'kharagpur',
#   'receives',
#   'comparatively',
#   'funding',
#   'engineering',
#   'college',
#   'india',
#   'total',
#   'government',
#   'funding',
#   'engineering',
#   'college',
#   'around',
#   'million',
#   'million',
#   'per',
#   'year',
#   'iit',
#   'kharagpur',
#   'get',
#   'nearly',
#   'million',
#   'u',
#   'million',
#   'per',
#   'year',
#   'source',
#   'fund',
#   'include',
#   'student',
#   'fee',
#   'research',
#   'funding',
#   'industry',
#   'sponsored',
#   'project',
#   'iit',
#   'kharagpur',
#   'provide',
#   'scholarship',
#   'mtech',
#   'student',
#   'research',
#   'scholar',
#   'encourage',
#   'pursue',
#   'higher',
#   'study',
#   'cost',
#   'borne',
#   'undergraduate',
#   'student',
#   'including',
#   'boarding',
#   'mess',
#   'expense',
#   'around',
#   'u',
#   'per',
#   'annum',
#   'undergraduate',
#   'student',
#   'given',
#   'additional',
#   'financial',
#   'support',
#   'based',
#   'personal',
#   'need',
#   'economic',
#   'background',
#   'annual',
#   'expense',
#   'nearly',
#   'u',
#   'academic',
#   'policy',
#   'iit',
#   'kharagpur',
#   'decided',
#   'senate',
#   'consists',
#   'professor',
#   'institute',
#   'administrative',
#   'student',
#   'representative',
#   'senate',
#   'control',
#   'approves',
#   'curriculum',
#   'course',
#   'examination',
#   'result',
#   'appoints',
#   'committee',
#   'look',
#   'specific',
#   'academic',
#   'matter',
#   'teaching',
#   'training',
#   'research',
#   'activity',
#   'institute',
#   'periodically',
#   'reviewed',
#   'senate',
#   'maintain',
#   'educational',
#   'standard',
#   'director',
#   'iit',
#   'kharagpur',
#   'ex',
#   'officio',
#   'chairman',
#   'institute',
#   'senate',
#   'iit',
#   'kharagpur',
#   'follows',
#   'credit',
#   'based',
#   'system',
#   'performance',
#   'evaluation',
#   'proportional',
#   'weighting',
#   'course',
#   'based',
#   'importance',
#   'total',
#   'mark',
#   'usually',
#   'form',
#   'basis',
#   'grade',
#   'grade',
#   'value',
#   'assigned',
#   'range',
#   'mark',
#   'semester',
#   'student',
#   'graded',
#   'taking',
#   'weighted',
#   'average',
#   'course',
#   'respective',
#   'credit',
#   'point',
#   'semester',
#   'evaluation',
#   'done',
#   'independently',
#   'cumulative',
#   'grade',
#   'point',
#   'average',
#   'cgpa',
#   'reflecting',
#   'average',
#   'performance',
#   'across',
#   'semester',
#   'campus',
#   'iit',
#   'kharagpur',
#   'located',
#   'kilometre',
#   'mi',
#   'west',
#   'kolkata',
#   'campus',
#   'located',
#   'five',
#   'kilometre',
#   'away',
#   'kharagpur',
#   'railway',
#   'station',
#   'west',
#   'midnapore',
#   'district',
#   'layout',
#   'present',
#   'campus',
#   'design',
#   'building',
#   'carried',
#   'group',
#   'engineer',
#   'architect',
#   'guidance',
#   'werner',
#   'moser',
#   'swiss',
#   'architect',
#   'square',
#   'kilometre',
#   'acre',
#   'campus',
#   'residence',
#   'inhabitant',
#   'iit',
#   'kharagpur',
#   'faculty',
#   'member',
#   'employee',
#   'approximately',
#   'student',
#   'living',
#   'campus',
#   'campus',
#   'ha',
#   'total',
#   'kilometre',
#   'mile',
#   'roadway',
#   'institute',
#   'plan',
#   'go',
#   'green',
#   'student',
#   'hostel',
#   'located',
#   'either',
#   'side',
#   'scholar',
#   'avenue',
#   'extends',
#   'institute',
#   'gate',
#   'b',
#   'c',
#   'roy',
#   'technology',
#   'hospital',
#   'three',
#   'earliest',
#   'hall',
#   'patel',
#   'azad',
#   'nehru',
#   'together',
#   'constitute',
#   'pan',
#   'loop',
#   'old',
#   'campus',
#   'located',
#   'next',
#   'scholar',
#   'avenue',
#   'ten',
#   'hostel',
#   'undergraduate',
#   'male',
#   'student',
#   'mmm',
#   'lb',
#   'rp',
#   'rk',
#   'llr',
#   'hjb',
#   'patel',
#   'azad',
#   'nehru',
#   'two',
#   'undergraduate',
#   'female',
#   'student',
#   'sn',
#   'ig',
#   'mt',
#   'post',
#   'graduate',
#   'student',
#   'hostel',
#   'including',
#   'four',
#   'woman',
#   'rlb',
#   'gokhle',
#   'nivedita',
#   'sam',
#   'hostel',
#   'research',
#   'scholar',
#   'bcr',
#   'v',
#   'brh',
#   'jcb',
#   'separate',
#   'hostel',
#   'scholar',
#   'armed',
#   'force',
#   'jnan',
#   'ghosh',
#   'stadium',
#   'tata',
#   'sport',
#   'complex',
#   'host',
#   'large',
#   'scale',
#   'sport',
#   'competition',
#   'tagore',
#   'open',
#   'air',
#   'theatre',
#   'ha',
#   'capacity',
#   'people',
#   'used',
#   'host',
#   'cultural',
#   'program',
#   'science',
#   'technology',
#   'entrepreneur',
#   'park',
#   'step',
#   'provides',
#   'infrastructure',
#   'facility',
#   'alumnus',
#   'want',
#   'become',
#   'entrepreneur',
#   'lack',
#   'infrastructure',
#   'start',
#   'corporation',
#   'addition',
#   'main',
#   'campus',
#   'kharagpur',
#   'institute',
#   'ha',
#   'extension',
#   'centre',
#   'kolkata',
#   'provide',
#   'venue',
#   'continuing',
#   'education',
#   'programme',
#   'distance',
#   'learning',
#   'course',
#   'guesthouse',
#   'accommodation',
#   'institute',
#   'plan',
#   'expand',
#   'kolkata',
#   'extension',
#   'centre',
#   'rajarhat',
#   'use',
#   'offer',
#   'full',
#   'time',
#   'undergraduate',
#   'postgraduate',
#   'course',
#   'session',
#   'onwards',
#   'hectare',
#   'acre',
#   'rajarhat',
#   'campus',
#   'house',
#   'student',
#   'eventually',
#   'expand',
#   'square',
#   'kilometre',
#   'acre',
#   'institute',
#   'plan',
#   'similar',
#   'branch',
#   'campus',
#   'square',
#   'kilometre',
#   'acre',
#   'bhubaneswar',
#   'wa',
#   'scrapped',
#   'following',
#   'rejection',
#   'union',
#   'human',
#   'resource',
#   'development',
#   'ministry',
#   'ministry',
#   'human',
#   'resource',
#   'development',
#   'september',
#   'awarded',
#   'institute',
#   'eminence',
#   'ioe',
#   'status',
#   'iit',
#   'kharagpur',
#   'along',
#   'four',
#   'public',
#   'institution',
#   'india',
#   'enable',
#   'get',
#   'full',
#   'autonomy',
#   'special',
#   'incentive',
#   'academic',
#   'building',
#   'iit',
#   'kharagpur',
#   'ha',
#   'academic',
#   'department',
#   'eight',
#   'multi',
#   'disciplinary',
#   'centre',
#   'school',
#   'school',
#   'excellence',
#   'addition',
#   'central',
#   'research',
#   'development',
#   'unit',
#   'apart',
#   'main',
#   'building',
#   'central',
#   'academic',
#   'complex',
#   'srinivasa',
#   'ramanujan',
#   'complex',
#   'also',
#   'ha',
#   'common',
#   'academic',
#   'facility',
#   'r',
#   'complex',
#   'takshashila',
#   'building',
#   'house',
#   'g',
#   'sanyal',
#   'school',
#   'telecommunication',
#   'school',
#   'information',
#   'technology',
#   'computer',
#   'informatics',
#   'centre',
#   'ha',
#   'facility',
#   'conducting',
#   'lecture',
#   'class',
#   'well',
#   'vikramshila',
#   'another',
#   'academic',
#   'building',
#   'r',
#   'complex',
#   'four',
#   'lecture',
#   'hall',
#   'several',
#   'seminar',
#   'room',
#   ...],
#  ['data',
#   'science',
#   'inter',
#   'disciplinary',
#   'field',
#   'us',
#   'scientific',
#   'method',
#   'process',
#   'algorithm',
#   'system',
#   'extract',
#   'knowledge',
#   'insight',
#   'many',
#   'structural',
#   'unstructured',
#   'data',
#   'data',
#   'science',
#   'related',
#   'data',
#   'mining',
#   'machine',
#   'learning',
#   'big',
#   'data',
#   'data',
#   'science',
#   'concept',
#   'unify',
#   'statistic',
#   'data',
#   'analysis',
#   'related',
#   'method',
#   'order',
#   'understand',
#   'analyze',
#   'actual',
#   'phenomenon',
#   'data',
#   'us',
#   'technique',
#   'theory',
#   'drawn',
#   'many',
#   'field',
#   'within',
#   'context',
#   'mathematics',
#   'statistic',
#   'computer',
#   'science',
#   'domain',
#   'knowledge',
#   'information',
#   'science',
#   'turing',
#   'award',
#   'winner',
#   'jim',
#   'gray',
#   'imagined',
#   'data',
#   'science',
#   'fourth',
#   'paradigm',
#   'science',
#   'empirical',
#   'theoretical',
#   'computational',
#   'data',
#   'driven',
#   'asserted',
#   'everything',
#   'science',
#   'changing',
#   'impact',
#   'information',
#   'technology',
#   'data',
#   'deluge',
#   'foundation',
#   'data',
#   'science',
#   'interdisciplinary',
#   'field',
#   'focused',
#   'extracting',
#   'knowledge',
#   'data',
#   'set',
#   'typically',
#   'large',
#   'see',
#   'big',
#   'data',
#   'field',
#   'encompasses',
#   'analysis',
#   'preparing',
#   'data',
#   'analysis',
#   'presenting',
#   'finding',
#   'inform',
#   'high',
#   'level',
#   'decision',
#   'organization',
#   'incorporates',
#   'skill',
#   'computer',
#   'science',
#   'mathematics',
#   'statistic',
#   'information',
#   'visualization',
#   'graphic',
#   'design',
#   'complex',
#   'system',
#   'communication',
#   'business',
#   'statistician',
#   'nathan',
#   'yau',
#   'drawing',
#   'ben',
#   'fry',
#   'also',
#   'link',
#   'data',
#   'science',
#   'human',
#   'computer',
#   'interaction',
#   'user',
#   'able',
#   'intuitively',
#   'control',
#   'explore',
#   'data',
#   'american',
#   'statistical',
#   'association',
#   'identified',
#   'database',
#   'management',
#   'statistic',
#   'machine',
#   'learning',
#   'distributed',
#   'parallel',
#   'system',
#   'three',
#   'emerging',
#   'foundational',
#   'professional',
#   'community',
#   'relationship',
#   'statistic',
#   'many',
#   'statistician',
#   'including',
#   'nate',
#   'silver',
#   'argued',
#   'data',
#   'science',
#   'new',
#   'field',
#   'rather',
#   'another',
#   'name',
#   'statistic',
#   'others',
#   'argue',
#   'data',
#   'science',
#   'distinct',
#   'statistic',
#   'focus',
#   'problem',
#   'technique',
#   'unique',
#   'digital',
#   'data',
#   'vasant',
#   'dhar',
#   'writes',
#   'statistic',
#   'emphasizes',
#   'quantitative',
#   'data',
#   'description',
#   'contrast',
#   'data',
#   'science',
#   'deal',
#   'quantitative',
#   'qualitative',
#   'data',
#   'e',
#   'g',
#   'image',
#   'emphasizes',
#   'prediction',
#   'action',
#   'andrew',
#   'gelman',
#   'columbia',
#   'university',
#   'data',
#   'scientist',
#   'vincent',
#   'granville',
#   'described',
#   'statistic',
#   'nonessential',
#   'part',
#   'data',
#   'science',
#   'stanford',
#   'professor',
#   'david',
#   'donoho',
#   'writes',
#   'data',
#   'science',
#   'distinguished',
#   'statistic',
#   'size',
#   'datasets',
#   'use',
#   'computing',
#   'many',
#   'graduate',
#   'program',
#   'misleadingly',
#   'advertise',
#   'analytics',
#   'statistic',
#   'training',
#   'essence',
#   'data',
#   'science',
#   'program',
#   'describes',
#   'data',
#   'science',
#   'applied',
#   'field',
#   'growing',
#   'traditional',
#   'statistic',
#   'summary',
#   'data',
#   'science',
#   'therefore',
#   'described',
#   'applied',
#   'branch',
#   'statistic',
#   'etymology',
#   'early',
#   'usage',
#   'john',
#   'tukey',
#   'described',
#   'field',
#   'called',
#   'data',
#   'analysis',
#   'resembles',
#   'modern',
#   'data',
#   'science',
#   'later',
#   'attendee',
#   'statistic',
#   'symposium',
#   'university',
#   'montpellier',
#   'ii',
#   'acknowledged',
#   'emergence',
#   'new',
#   'discipline',
#   'focused',
#   'data',
#   'various',
#   'origin',
#   'form',
#   'combining',
#   'established',
#   'concept',
#   'principle',
#   'statistic',
#   'data',
#   'analysis',
#   'computing',
#   'term',
#   'data',
#   'science',
#   'ha',
#   'traced',
#   'back',
#   'peter',
#   'naur',
#   'proposed',
#   'alternative',
#   'name',
#   'computer',
#   'science',
#   'international',
#   'federation',
#   'classification',
#   'society',
#   'became',
#   'first',
#   'conference',
#   'specifically',
#   'feature',
#   'data',
#   'science',
#   'topic',
#   'however',
#   'definition',
#   'wa',
#   'still',
#   'flux',
#   'c',
#   'f',
#   'jeff',
#   'wu',
#   'suggested',
#   'statistic',
#   'renamed',
#   'data',
#   'science',
#   'reasoned',
#   'new',
#   'name',
#   'would',
#   'help',
#   'statistic',
#   'shed',
#   'inaccurate',
#   'stereotype',
#   'synonymous',
#   'accounting',
#   'limited',
#   'describing',
#   'data',
#   'chikio',
#   'hayashi',
#   'argued',
#   'data',
#   'science',
#   'new',
#   'interdisciplinary',
#   'concept',
#   'three',
#   'aspect',
#   'data',
#   'design',
#   'collection',
#   'analysis',
#   'popular',
#   'term',
#   'process',
#   'finding',
#   'pattern',
#   'datasets',
#   'increasingly',
#   'large',
#   'included',
#   'knowledge',
#   'discovery',
#   'data',
#   'mining',
#   'modern',
#   'usage',
#   'modern',
#   'conception',
#   'data',
#   'science',
#   'independent',
#   'discipline',
#   'sometimes',
#   'attributed',
#   'william',
#   'cleveland',
#   'paper',
#   'advocated',
#   'expansion',
#   'statistic',
#   'beyond',
#   'theory',
#   'technical',
#   'area',
#   'would',
#   'significantly',
#   'change',
#   'field',
#   'warranted',
#   'new',
#   'name',
#   'data',
#   'science',
#   'became',
#   'widely',
#   'used',
#   'next',
#   'year',
#   'committee',
#   'data',
#   'science',
#   'technology',
#   'launched',
#   'data',
#   'science',
#   'journal',
#   'columbia',
#   'university',
#   'launched',
#   'journal',
#   'data',
#   'science',
#   'american',
#   'statistical',
#   'association',
#   'section',
#   'statistical',
#   'learning',
#   'data',
#   'mining',
#   'changed',
#   'name',
#   'section',
#   'statistical',
#   'learning',
#   'data',
#   'science',
#   'reflecting',
#   'ascendant',
#   'popularity',
#   'data',
#   'science',
#   'professional',
#   'title',
#   'data',
#   'scientist',
#   'ha',
#   'attributed',
#   'dj',
#   'patil',
#   'jeff',
#   'hammerbacher',
#   'though',
#   'wa',
#   'used',
#   'national',
#   'science',
#   'board',
#   'report',
#   'long',
#   'lived',
#   'digital',
#   'data',
#   'collection',
#   'enabling',
#   'research',
#   'education',
#   'st',
#   'century',
#   'referred',
#   'broadly',
#   'key',
#   'role',
#   'managing',
#   'digital',
#   'data',
#   'collection',
#   'still',
#   'consensus',
#   'definition',
#   'data',
#   'science',
#   'considered',
#   'buzzword',
#   'impact',
#   'data',
#   'science',
#   'big',
#   'data',
#   'quickly',
#   'becoming',
#   'vital',
#   'tool',
#   'business',
#   'company',
#   'size',
#   'availability',
#   'interpretation',
#   'big',
#   'data',
#   'ha',
#   'altered',
#   'business',
#   'model',
#   'old',
#   'industry',
#   'enabled',
#   'creation',
#   'new',
#   'one',
#   'data',
#   'driven',
#   'business',
#   'worth',
#   'trillion',
#   'collectively',
#   'increase',
#   'billion',
#   'year',
#   'data',
#   'scientist',
#   'responsible',
#   'breaking',
#   'big',
#   'data',
#   'usable',
#   'information',
#   'creating',
#   'software',
#   'algorithm',
#   'help',
#   'company',
#   'organization',
#   'determine',
#   'optimal',
#   'operation',
#   'big',
#   'data',
#   'continues',
#   'major',
#   'impact',
#   'world',
#   'data',
#   'science',
#   'doe',
#   'well',
#   'due',
#   'close',
#   'relationship',
#   'two',
#   'technology',
#   'technique',
#   'variety',
#   'different',
#   'technology',
#   'technique',
#   'used',
#   'data',
#   'science',
#   'depend',
#   'application',
#   'recently',
#   'full',
#   'featured',
#   'end',
#   'end',
#   'platform',
#   'developed',
#   'heavily',
#   'used',
#   'data',
#   'science',
#   'machine',
#   'learning',
#   'technique',
#   'linear',
#   'regression',
#   'logistic',
#   'regression',
#   'decision',
#   'tree',
#   'used',
#   'prediction',
#   'model',
#   'classification',
#   'data',
#   'fitting',
#   'decision',
#   'tree',
#   'structure',
#   'used',
#   'generate',
#   'rule',
#   'able',
#   'classify',
#   'predict',
#   'target',
#   'class',
#   'label',
#   'variable',
#   'based',
#   'observation',
#   'attribute',
#   'support',
#   'vector',
#   'machine',
#   'svm',
#   'clustering',
#   'technique',
#   'used',
#   'group',
#   'data',
#   'together',
#   'dimensionality',
#   'reduction',
#   'used',
#   'reduce',
#   'complexity',
#   'data',
#   'computation',
#   'performed',
#   'quickly',
#   'machine',
#   'learning',
#   'technique',
#   'used',
#   'perform',
#   'task',
#   'inferencing',
#   'pattern',
#   'data',
#   'language',
#   'python',
#   'programming',
#   'language',
#   'simple',
#   'syntax',
#   'commonly',
#   'used',
#   'data',
#   'science',
#   'number',
#   'python',
#   'library',
#   'used',
#   'data',
#   'science',
#   'including',
#   'numpy',
#   'panda',
#   'matplotlib',
#   'scipy',
#   'r',
#   'programming',
#   'language',
#   'wa',
#   'designed',
#   'statistician',
#   'data',
#   'mining',
#   'optimized',
#   'computation',
#   'julia',
#   'high',
#   'level',
#   'high',
#   'performance',
#   'dynamic',
#   'programming',
#   'language',
#   'well',
#   'suited',
#   'numerical',
#   'analysis',
#   'computational',
#   'science',
#   'framework',
#   'tensorflow',
#   'framework',
#   'creating',
#   'machine',
#   'learning',
#   'model',
#   'developed',
#   'google',
#   'pytorch',
#   'another',
#   'framework',
#   'machine',
#   'learning',
#   'developed',
#   'facebook',
#   'jupyter',
#   'notebook',
#   'interactive',
#   'web',
#   'interface',
#   'python',
#   'allows',
#   'faster',
#   'experimentation',
#   'apache',
#   'hadoop',
#   'software',
#   'framework',
#   'used',
#   'process',
#   'data',
#   'large',
#   'distributed',
#   'system',
#   'visualization',
#   'tool',
#   'plotly',
#   'provides',
#   'rich',
#   'set',
#   'interactive',
#   'scientific',
#   'graphing',
#   'library',
#   'tableau',
#   'make',
#   'variety',
#   'software',
#   'used',
#   'data',
#   'visualization',
#   'powerbi',
#   'business',
#   'analytics',
#   'service',
#   'microsoft',
#   'qlik',
#   'produce',
#   'software',
#   'qlikview',
#   'qlik',
#   'sense',
#   'used',
#   'data',
#   'visualization',
#   'business',
#   'intelligence',
#   'anychart',
#   'provides',
#   'javascript',
#   'library',
#   'tool',
#   'data',
#   'visualization',
#   'chart',
#   'dashboard',
#   'google',
#   'chart',
#   'javascript',
#   'based',
#   'web',
#   'service',
#   'made',
#   'supported',
#   'google',
#   'creating',
#   'graphical',
#   'chart',
#   'sisense',
#   'provides',
#   'front',
#   'end',
#   'building',
#   'data',
#   'visualization',
#   'including',
#   'dashboard',
#   'report',
#   'webix',
#   'ui',
#   'toolkit',
#   'includes',
#   'dedicated',
#   'tool',
#   'information',
#   'visualization',
#   'platform',
#   'rapidminer',
#   'data',
#   'science',
#   'software',
#   'platform',
#   'developed',
#   'company',
#   'name',
#   'dataiku',
#   'collaborative',
#   'data',
#   'science',
#   'software',
#   'marketed',
#   'big',
#   'data',
#   'anaconda',
#   'provides',
#   'comprehensive',
#   'free',
#   'open',
#   'source',
#   'distribution',
#   'python',
#   'r',
#   'programming',
#   'language',
#   'matlab',
#   'computing',
#   'environment',
#   'heavily',
#   'used',
#   'industry',
#   'academia',
#   'databricks',
#   'cloud',
#   'platform',
#   'massive',
#   'scale',
#   'data',
#   'engineering',
#   'collaborative',
#   'data',
#   'science',
#   'ibm',
#   'watson',
#   'studio',
#   'cloud',
#   'platform',
#   'offer',
#   'comprehensive',
#   'suite',
#   'collaborative',
#   'data',
#   'science',
#   'tool',
#   'infusing',
#   'ai',
#   'business',
#   'application',
#   'reference'],
#  ['coronavirus',
#   'disease',
#   'covid',
#   'contagious',
#   'respiratory',
#   'vascular',
#   'disease',
#   'caused',
#   'severe',
#   'acute',
#   'respiratory',
#   'syndrome',
#   'coronavirus',
#   'sars',
#   'cov',
#   'first',
#   'case',
#   'wa',
#   'identified',
#   'wuhan',
#   'china',
#   'december',
#   'though',
#   'evidence',
#   'suggests',
#   'virus',
#   'may',
#   'already',
#   'actively',
#   'spreading',
#   'month',
#   'earlier',
#   'place',
#   'italy',
#   'common',
#   'symptom',
#   'covid',
#   'include',
#   'fever',
#   'cough',
#   'fatigue',
#   'breathing',
#   'difficulty',
#   'loss',
#   'smell',
#   'taste',
#   'symptom',
#   'begin',
#   'one',
#   'fourteen',
#   'day',
#   'exposure',
#   'virus',
#   'people',
#   'mild',
#   'symptom',
#   'people',
#   'develop',
#   'acute',
#   'respiratory',
#   'distress',
#   'syndrome',
#   'ards',
#   'ards',
#   'precipitated',
#   'cytokine',
#   'storm',
#   'multi',
#   'organ',
#   'failure',
#   'septic',
#   'shock',
#   'blood',
#   'clot',
#   'longer',
#   'term',
#   'damage',
#   'organ',
#   'particular',
#   'lung',
#   'heart',
#   'ha',
#   'observed',
#   'concern',
#   'significant',
#   'number',
#   'patient',
#   'recovered',
#   'acute',
#   'phase',
#   'disease',
#   'continue',
#   'experience',
#   'range',
#   'effect',
#   'known',
#   'long',
#   'covid',
#   'month',
#   'afterwards',
#   'effect',
#   'include',
#   'severe',
#   'fatigue',
#   'memory',
#   'loss',
#   'cognitive',
#   'issue',
#   'low',
#   'grade',
#   'fever',
#   'muscle',
#   'weakness',
#   'breathlessness',
#   'covid',
#   'spread',
#   'via',
#   'number',
#   'mean',
#   'primarily',
#   'involving',
#   'saliva',
#   'bodily',
#   'fluid',
#   'excretion',
#   'fluid',
#   'form',
#   'small',
#   'droplet',
#   'aerosol',
#   'spread',
#   'infected',
#   'person',
#   'breathes',
#   'cough',
#   'sneeze',
#   'sings',
#   'speaks',
#   'virus',
#   'may',
#   'also',
#   'spread',
#   'via',
#   'fomite',
#   'contaminated',
#   'surface',
#   'direct',
#   'contact',
#   'infection',
#   'mainly',
#   'happens',
#   'people',
#   'near',
#   'long',
#   'enough',
#   'spread',
#   'early',
#   'two',
#   'day',
#   'infected',
#   'person',
#   'show',
#   'symptom',
#   'presymptomatic',
#   'asymptomatic',
#   'individual',
#   'people',
#   'remain',
#   'infectious',
#   'ten',
#   'day',
#   'moderate',
#   'case',
#   'two',
#   'week',
#   'severe',
#   'case',
#   'standard',
#   'diagnosis',
#   'method',
#   'real',
#   'time',
#   'reverse',
#   'transcription',
#   'polymerase',
#   'chain',
#   'reaction',
#   'rrt',
#   'pcr',
#   'nasopharyngeal',
#   'swab',
#   'preventive',
#   'measure',
#   'include',
#   'social',
#   'distancing',
#   'quarantining',
#   'ventilation',
#   'indoor',
#   'space',
#   'covering',
#   'cough',
#   'sneeze',
#   'hand',
#   'washing',
#   'keeping',
#   'unwashed',
#   'hand',
#   'away',
#   'face',
#   'use',
#   'face',
#   'mask',
#   'covering',
#   'ha',
#   'recommended',
#   'public',
#   'setting',
#   'minimise',
#   'risk',
#   'transmission',
#   'currently',
#   'proven',
#   'vaccine',
#   'specific',
#   'treatment',
#   'covid',
#   'though',
#   'several',
#   'development',
#   'management',
#   'involves',
#   'treatment',
#   'symptom',
#   'supportive',
#   'care',
#   'isolation',
#   'experimental',
#   'measure',
#   'sign',
#   'symptom',
#   'cause',
#   'covid',
#   'caused',
#   'infection',
#   'severe',
#   'acute',
#   'respiratory',
#   'syndrome',
#   'coronavirus',
#   'sars',
#   'cov',
#   'virus',
#   'strain',
#   'transmission',
#   'virology',
#   'severe',
#   'acute',
#   'respiratory',
#   'syndrome',
#   'coronavirus',
#   'sars',
#   'cov',
#   'novel',
#   'severe',
#   'acute',
#   'respiratory',
#   'syndrome',
#   'coronavirus',
#   'wa',
#   'first',
#   'isolated',
#   'three',
#   'people',
#   'pneumonia',
#   'connected',
#   'cluster',
#   'acute',
#   'respiratory',
#   'illness',
#   'case',
#   'wuhan',
#   'feature',
#   'novel',
#   'sars',
#   'cov',
#   'virus',
#   'occur',
#   'related',
#   'coronaviruses',
#   'nature',
#   'outside',
#   'human',
#   'body',
#   'virus',
#   'destroyed',
#   'household',
#   'soap',
#   'burst',
#   'protective',
#   'bubble',
#   'sars',
#   'cov',
#   'closely',
#   'related',
#   'original',
#   'sars',
#   'cov',
#   'thought',
#   'animal',
#   'zoonotic',
#   'origin',
#   'genetic',
#   'analysis',
#   'ha',
#   'revealed',
#   'coronavirus',
#   'genetically',
#   'cluster',
#   'genus',
#   'betacoronavirus',
#   'subgenus',
#   'sarbecovirus',
#   'lineage',
#   'b',
#   'together',
#   'two',
#   'bat',
#   'derived',
#   'strain',
#   'identical',
#   'whole',
#   'genome',
#   'level',
#   'bat',
#   'coronavirus',
#   'sample',
#   'batcov',
#   'ratg',
#   'structural',
#   'protein',
#   'sars',
#   'cov',
#   'include',
#   'membrane',
#   'glycoprotein',
#   'envelope',
#   'protein',
#   'e',
#   'nucleocapsid',
#   'protein',
#   'n',
#   'spike',
#   'protein',
#   'protein',
#   'sars',
#   'cov',
#   'similar',
#   'protein',
#   'bat',
#   'sars',
#   'cov',
#   'maintains',
#   'homology',
#   'pangolin',
#   'sars',
#   'cov',
#   'ha',
#   'homology',
#   'protein',
#   'sars',
#   'cov',
#   'whereas',
#   'similarity',
#   'protein',
#   'mers',
#   'cov',
#   'silico',
#   'analysis',
#   'showed',
#   'protein',
#   'sars',
#   'cov',
#   'ha',
#   'triple',
#   'helix',
#   'bundle',
#   'form',
#   'single',
#   'transmembrane',
#   'domain',
#   'homologous',
#   'prokaryotic',
#   'sugar',
#   'transport',
#   'protein',
#   'semisweet',
#   'pathophysiology',
#   'covid',
#   'affect',
#   'upper',
#   'respiratory',
#   'tract',
#   'sinus',
#   'nose',
#   'throat',
#   'lower',
#   'respiratory',
#   'tract',
#   'windpipe',
#   'lung',
#   'lung',
#   'organ',
#   'affected',
#   'covid',
#   'virus',
#   'access',
#   'host',
#   'cell',
#   'via',
#   'enzyme',
#   'angiotensin',
#   'converting',
#   'enzyme',
#   'ace',
#   'abundant',
#   'type',
#   'ii',
#   'alveolar',
#   'cell',
#   'lung',
#   'virus',
#   'us',
#   'special',
#   'surface',
#   'glycoprotein',
#   'called',
#   'spike',
#   'peplomer',
#   'connect',
#   'ace',
#   'enter',
#   'host',
#   'cell',
#   'density',
#   'ace',
#   'tissue',
#   'correlate',
#   'severity',
#   'disease',
#   'tissue',
#   'suggested',
#   'decreasing',
#   'ace',
#   'activity',
#   'might',
#   'protective',
#   'though',
#   'another',
#   'view',
#   'increasing',
#   'ace',
#   'using',
#   'angiotensin',
#   'ii',
#   'receptor',
#   'blocker',
#   'medication',
#   'could',
#   'protective',
#   'alveolar',
#   'disease',
#   'progress',
#   'respiratory',
#   'failure',
#   'might',
#   'develop',
#   'death',
#   'may',
#   'follow',
#   'whether',
#   'sars',
#   'cov',
#   'able',
#   'invade',
#   'nervous',
#   'system',
#   'remains',
#   'unknown',
#   'virus',
#   'detected',
#   'cns',
#   'majority',
#   'covid',
#   'patient',
#   'neurological',
#   'issue',
#   'however',
#   'sars',
#   'cov',
#   'ha',
#   'detected',
#   'low',
#   'level',
#   'brain',
#   'patient',
#   'died',
#   'covid',
#   'result',
#   'need',
#   'confirmed',
#   'sars',
#   'cov',
#   'may',
#   'cause',
#   'respiratory',
#   'failure',
#   'affecting',
#   'brain',
#   'stem',
#   'coronaviruses',
#   'found',
#   'invade',
#   'cns',
#   'virus',
#   'ha',
#   'detected',
#   'cerebrospinal',
#   'fluid',
#   'autopsy',
#   'exact',
#   'mechanism',
#   'invades',
#   'cns',
#   'remains',
#   'unclear',
#   'may',
#   'first',
#   'involve',
#   'invasion',
#   'peripheral',
#   'nerve',
#   'given',
#   'low',
#   'level',
#   'ace',
#   'brain',
#   'virus',
#   'may',
#   'also',
#   'enter',
#   'bloodstream',
#   'lung',
#   'cross',
#   'blood',
#   'brain',
#   'barrier',
#   'gain',
#   'access',
#   'cns',
#   'possibly',
#   'within',
#   'infected',
#   'white',
#   'blood',
#   'cell',
#   'trojan',
#   'horse',
#   'mechanism',
#   'virus',
#   'also',
#   'affect',
#   'gastrointestinal',
#   'organ',
#   'ace',
#   'abundantly',
#   'expressed',
#   'glandular',
#   'cell',
#   'gastric',
#   'duodenal',
#   'rectal',
#   'epithelium',
#   'well',
#   'endothelial',
#   'cell',
#   'enterocytes',
#   'small',
#   'intestine',
#   'virus',
#   'cause',
#   'acute',
#   'myocardial',
#   'injury',
#   'chronic',
#   'damage',
#   'cardiovascular',
#   'system',
#   'acute',
#   'cardiac',
#   'injury',
#   'wa',
#   'found',
#   'infected',
#   'people',
#   'admitted',
#   'hospital',
#   'wuhan',
#   'china',
#   'frequent',
#   'severe',
#   'disease',
#   'rate',
#   'cardiovascular',
#   'symptom',
#   'high',
#   'owing',
#   'systemic',
#   'inflammatory',
#   'response',
#   'immune',
#   'system',
#   'disorder',
#   'disease',
#   'progression',
#   'acute',
#   'myocardial',
#   'injury',
#   'may',
#   'also',
#   'related',
#   'ace',
#   'receptor',
#   'heart',
#   'ace',
#   'receptor',
#   'highly',
#   'expressed',
#   'heart',
#   'involved',
#   'heart',
#   'function',
#   'high',
#   'incidence',
#   'thrombosis',
#   'venous',
#   'thromboembolism',
#   'found',
#   'icu',
#   'patient',
#   'covid',
#   'infection',
#   'may',
#   'related',
#   'poor',
#   'prognosis',
#   'blood',
#   'vessel',
#   'dysfunction',
#   'clot',
#   'formation',
#   'suggested',
#   'high',
#   'dimer',
#   'level',
#   'thought',
#   'play',
#   'significant',
#   'role',
#   'mortality',
#   'incidence',
#   'clot',
#   'leading',
#   'pulmonary',
#   'embolism',
#   'ischaemic',
#   'event',
#   'within',
#   'brain',
#   'noted',
#   'complication',
#   'leading',
#   'death',
#   'patient',
#   'infected',
#   'sars',
#   'cov',
#   'infection',
#   'appears',
#   'set',
#   'chain',
#   'vasoconstrictive',
#   'response',
#   'within',
#   'body',
#   'constriction',
#   'blood',
#   'vessel',
#   'within',
#   'pulmonary',
#   'circulation',
#   'ha',
#   'also',
#   'posited',
#   'mechanism',
#   'oxygenation',
#   'decrease',
#   'alongside',
#   'presentation',
#   'viral',
#   'pneumonia',
#   'another',
#   'common',
#   'cause',
#   'death',
#   'complication',
#   'related',
#   'kidney',
#   'early',
#   'report',
#   'show',
#   'hospitalized',
#   'patient',
#   'china',
#   'new',
#   'york',
#   'experienced',
#   'injury',
#   'kidney',
#   'including',
#   'person',
#   'previous',
#   'kidney',
#   'problem',
#   'autopsy',
#   'people',
#   'died',
#   'covid',
#   'found',
#   'diffuse',
#   'alveolar',
#   'damage',
#   'dad',
#   'lymphocyte',
#   'containing',
#   'inflammatory',
#   'infiltrates',
#   'within',
#   'lung',
#   'immunopathology',
#   'although',
#   'sars',
#   'cov',
#   'ha',
#   'tropism',
#   'ace',
#   'expressing',
#   'epithelial',
#   'cell',
#   'respiratory',
#   'tract',
#   'patient',
#   'severe',
#   'covid',
#   'symptom',
#   'systemic',
#   'hyperinflammation',
#   'clinical',
#   'laboratory',
#   'finding',
#   'elevated',
#   'il',
#   'il',
#   'il',
#   'granulocyte',
#   'macrophage',
#   'colony',
#   'stimulating',
#   'factor',
#   'gm',
#   'csf',
#   'interferon',
#   'inducible',
#   'protein',
#   'ip',
#   'monocyte',
#   'chemoattractant',
#   'protein',
#   'mcp',
#   'macrophage',
#   'inflammatory',
#   'protein',
#   'mip',
#   'tumour',
#   'necrosis',
#   'factor',
#   'tnf',
#   'indicative',
#   'cytokine',
#   'release',
#   'syndrome',
#   'cr',
#   'suggest',
#   'underlying',
#   'immunopathology',
#   'additionally',
#   'people',
#   'covid',
#   'acute',
#   'respiratory',
#   'distress',
#   'syndrome',
#   'ards',
#   'classical',
#   'serum',
#   'biomarkers',
#   'cr',
#   'including',
#   'elevated',
#   'c',
#   'reactive',
#   'protein',
#   'crp',
#   'lactate',
#   'dehydrogenase',
#   'ldh',
#   'dimer',
#   'ferritin',
#   'systemic',
#   'inflammation',
#   'result',
#   'vasodilation',
#   'allowing',
#   'inflammatory',
#   'lymphocytic',
#   'monocytic',
#   'infiltration',
#   'lung',
#   'heart',
#   'particular',
#   'pathogenic',
#   'gm',
#   'csf',
#   'secreting',
#   'cell',
#   'shown',
#   'correlate',
#   'recruitment',
#   'inflammatory',
#   'il',
#   'secreting',
#   'monocyte',
#   'severe',
#   'lung',
#   'pathology',
#   'covid',
#   'patient',
#   'lymphocytic',
#   'infiltrates',
#   'also',
#   'reported',
#   'autopsy',
#   'diagnosis',
#   'ha',
#   'published',
#   'several',
#   'testing',
#   'protocol',
#   'disease',
#   'standard',
#   'method',
#   'testing',
#   'real',
#   'time',
#   'reverse',
#   'transcription',
#   'polymerase',
#   'chain',
#   'reaction',
#   'rrt',
#   'pcr',
#   'test',
#   'typically',
#   'done',
#   'respiratory',
#   'sample',
#   'obtained',
#   'nasopharyngeal',
#   'swab',
#   'however',
#   'nasal',
#   'swab',
#   'sputum',
#   'sample',
#   'may',
#   'also',
#   'used',
#   'result',
#   'generally',
#   'available',
#   'within',
#   'hour',
#   'two',
#   'day',
#   'blood',
#   'test',
#   'used',
#   'require',
#   'two',
#   'blood',
#   'sample',
#   'taken',
#   'two',
#   'week',
#   'apart',
#   'result',
#   'little',
#   'immediate',
#   'value',
#   'chinese',
#   'scientist',
#   'able',
#   'isolate',
#   'strain',
#   'coronavirus',
#   'publish',
#   'genetic',
#   'sequence',
#   'laboratory',
#   'across',
#   'world',
#   'could',
#   'independently',
#   'develop',
#   'polymerase',
#   'chain',
#   'reaction',
#   'pcr',
#   'test',
#   'detect',
#   'infection',
#   'virus',
#   'april',
#   'antibody',
#   'test',
#   'may',
#   'detect',
#   'active',
#   'infection',
#   'whether',
#   'person',
#   'infected',
#   'past',
#   'development',
#   'yet',
#   'widely',
#   'used',
#   'antibody',
#   'test',
#   'may',
#   'accurate',
#   'week',
#   'person',
#   'symptom',
#   'start',
#   'chinese',
#   'experience',
#   'testing',
#   'ha',
#   'shown',
#   'accuracy',
#   'u',
#   'food',
#   'drug',
#   'administration',
#   'fda',
#   'approved',
#   'first',
#   'point',
#   'care',
#   'test',
#   'march',
#   'use',
#   'end',
#   'month',
#   'absence',
#   'presence',
#   'covid',
#   'sign',
#   'symptom',
#   'alone',
#   'reliable',
#   'enough',
#   'accurate',
#   'diagnosis',
#   'different',
#   'clinical',
#   'score',
#   'created',
#   'based',
#   ...]]

# %%
from gensim import corpora

# %%
input_dict=corpora.Dictionary(processed_data)
input_corpus=[input_dict.doc2bow(token,allow_update=True) for token in processed_data]

# %%
input_corpus[0:10]
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 1),
#   (3, 1),
#   (4, 1),
#   (5, 2),
#   (6, 3),
#   (7, 1),
#   (8, 2),
#   (9, 3),
#   (10, 1),
#   (11, 3),
#   (12, 1),
#   (13, 2),
#   (14, 2),
#   (15, 2),
#   (16, 1),
#   (17, 1),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 2),
#   (26, 2),
#   (27, 1),
#   (28, 1),
#   (29, 2),
#   (30, 1),
#   (31, 1),
#   (32, 12),
#   (33, 2),
#   (34, 4),
#   (35, 2),
#   (36, 1),
#   (37, 2),
#   (38, 1),
#   (39, 1),
#   (40, 4),
#   (41, 2),
#   (42, 17),
#   (43, 1),
#   (44, 3),
#   (45, 1),
#   (46, 2),
#   (47, 1),
#   (48, 1),
#   (49, 2),
#   (50, 1),
#   (51, 3),
#   (52, 1),
#   (53, 2),
#   (54, 2),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 2),
#   (59, 1),
#   (60, 1),
#   (61, 6),
#   (62, 6),
#   (63, 3),
#   (64, 1),
#   (65, 1),
#   (66, 3),
#   (67, 2),
#   (68, 1),
#   (69, 1),
#   (70, 2),
#   (71, 2),
#   (72, 9),
#   (73, 3),
#   (74, 3),
#   (75, 1),
#   (76, 3),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 2),
#   (82, 1),
#   (83, 4),
#   (84, 2),
#   (85, 1),
#   (86, 1),
#   (87, 4),
#   (88, 2),
#   (89, 1),
#   (90, 3),
#   (91, 1),
#   (92, 1),
#   (93, 2),
#   (94, 1),
#   (95, 9),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 2),
#   (101, 2),
#   (102, 1),
#   (103, 1),
#   (104, 2),
#   (105, 3),
#   (106, 1),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 5),
#   (111, 3),
#   (112, 1),
#   (113, 2),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1),
#   (124, 2),
#   (125, 4),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 3),
#   (130, 1),
#   (131, 1),
#   (132, 2),
#   (133, 3),
#   (134, 1),
#   (135, 5),
#   (136, 10),
#   (137, 2),
#   (138, 12),
#   (139, 1),
#   (140, 1),
#   (141, 2),
#   (142, 1),
#   (143, 2),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 2),
#   (151, 1),
#   (152, 2),
#   (153, 1),
#   (154, 2),
#   (155, 1),
#   (156, 5),
#   (157, 1),
#   (158, 2),
#   (159, 3),
#   (160, 1),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (164, 1),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 2),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 4),
#   (178, 1),
#   (179, 1),
#   (180, 2),
#   (181, 1),
#   (182, 4),
#   (183, 1),
#   (184, 2),
#   (185, 1),
#   (186, 2),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 4),
#   (191, 1),
#   (192, 7),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 3),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 2),
#   (214, 1),
#   (215, 2),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 8),
#   (220, 2),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 2),
#   (225, 1),
#   (226, 83),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 4),
#   (231, 3),
#   (232, 1),
#   (233, 2),
#   (234, 1),
#   (235, 1),
#   (236, 2),
#   (237, 2),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 1),
#   (247, 1),
#   (248, 1),
#   (249, 15),
#   (250, 1),
#   (251, 1),
#   (252, 4),
#   (253, 1),
#   (254, 3),
#   (255, 1),
#   (256, 1),
#   (257, 2),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 3),
#   (272, 1),
#   (273, 2),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 1),
#   (279, 4),
#   (280, 2),
#   (281, 1),
#   (282, 2),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 13),
#   (287, 1),
#   (288, 1),
#   (289, 13),
#   (290, 4),
#   (291, 1),
#   (292, 1),
#   (293, 1),
#   (294, 3),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 3),
#   (299, 1),
#   (300, 2),
#   (301, 1),
#   (302, 8),
#   (303, 2),
#   (304, 3),
#   (305, 1),
#   (306, 6),
#   (307, 1),
#   (308, 6),
#   (309, 2),
#   (310, 3),
#   (311, 4),
#   (312, 1),
#   (313, 5),
#   (314, 2),
#   (315, 1),
#   (316, 6),
#   (317, 1),
#   (318, 3),
#   (319, 1),
#   (320, 1),
#   (321, 4),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 3),
#   (326, 1),
#   (327, 2),
#   (328, 1),
#   (329, 1),
#   (330, 1),
#   (331, 1),
#   (332, 1),
#   (333, 1),
#   (334, 3),
#   (335, 1),
#   (336, 3),
#   (337, 1),
#   (338, 2),
#   (339, 19),
#   (340, 1),
#   (341, 1),
#   (342, 1),
#   (343, 3),
#   (344, 4),
#   (345, 5),
#   (346, 1),
#   (347, 5),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 3),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 3),
#   (357, 1),
#   (358, 1),
#   (359, 1),
#   (360, 1),
#   (361, 2),
#   (362, 2),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 7),
#   (367, 1),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 1),
#   (372, 1),
#   (373, 2),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 2),
#   (378, 1),
#   (379, 2),
#   (380, 16),
#   (381, 21),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 5),
#   (390, 2),
#   (391, 1),
#   (392, 4),
#   (393, 1),
#   (394, 4),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 4),
#   (400, 2),
#   (401, 1),
#   (402, 2),
#   (403, 2),
#   (404, 2),
#   (405, 1),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 7),
#   (413, 2),
#   (414, 2),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 3),
#   (419, 1),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 1),
#   (425, 1),
#   (426, 2),
#   (427, 3),
#   (428, 6),
#   (429, 1),
#   (430, 1),
#   (431, 2),
#   (432, 1),
#   (433, 1),
#   (434, 28),
#   (435, 3),
#   (436, 2),
#   (437, 1),
#   (438, 1),
#   (439, 1),
#   (440, 2),
#   (441, 2),
#   (442, 1),
#   (443, 7),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 10),
#   (451, 1),
#   (452, 1),
#   (453, 5),
#   (454, 1),
#   (455, 3),
#   (456, 1),
#   (457, 2),
#   (458, 1),
#   (459, 1),
#   (460, 1),
#   (461, 4),
#   (462, 1),
#   (463, 1),
#   (464, 3),
#   (465, 1),
#   (466, 3),
#   (467, 1),
#   (468, 1),
#   (469, 5),
#   (470, 3),
#   (471, 1),
#   (472, 1),
#   (473, 1),
#   (474, 2),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 4),
#   (483, 2),
#   (484, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1),
#   (488, 1),
#   (489, 1),
#   (490, 1),
#   (491, 1),
#   (492, 5),
#   (493, 1),
#   (494, 18),
#   (495, 2),
#   (496, 1),
#   (497, 1),
#   (498, 2),
#   (499, 1),
#   (500, 1),
#   (501, 1),
#   (502, 2),
#   (503, 1),
#   (504, 1),
#   (505, 2),
#   (506, 1),
#   (507, 1),
#   (508, 2),
#   (509, 6),
#   (510, 1),
#   (511, 3),
#   (512, 1),
#   (513, 1),
#   (514, 2),
#   (515, 4),
#   (516, 1),
#   (517, 1),
#   (518, 1),
#   (519, 1),
#   (520, 4),
#   (521, 2),
#   (522, 1),
#   (523, 2),
#   (524, 1),
#   (525, 1),
#   (526, 5),
#   (527, 1),
#   (528, 1),
#   (529, 2),
#   (530, 1),
#   (531, 1),
#   (532, 3),
#   (533, 1),
#   (534, 2),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 1),
#   (541, 1),
#   (542, 2),
#   (543, 1),
#   (544, 3),
#   (545, 1),
#   (546, 1),
#   (547, 1),
#   (548, 1),
#   (549, 1),
#   (550, 5),
#   (551, 2),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 1),
#   (562, 1),
#   (563, 1),
#   (564, 2),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1),
#   (569, 11),
#   (570, 1),
#   (571, 4),
#   (572, 1),
#   (573, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 2),
#   (578, 1),
#   (579, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 1),
#   (586, 3),
#   (587, 1),
#   (588, 3),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 4),
#   (593, 6),
#   (594, 1),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 2),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 1),
#   (606, 2),
#   (607, 1),
#   (608, 1),
#   (609, 1),
#   (610, 1),
#   (611, 2),
#   (612, 4),
#   (613, 1),
#   (614, 1),
#   (615, 2),
#   (616, 1),
#   (617, 1),
#   (618, 2),
#   (619, 1),
#   (620, 1),
#   (621, 3),
#   (622, 1),
#   (623, 3),
#   (624, 1),
#   (625, 3),
#   (626, 2),
#   (627, 5),
#   (628, 35),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 2),
#   (633, 2),
#   (634, 2),
#   (635, 1),
#   (636, 3),
#   (637, 1),
#   (638, 3),
#   (639, 2),
#   (640, 12),
#   (641, 1),
#   (642, 7),
#   (643, 1),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 3),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1),
#   (658, 8),
#   (659, 2),
#   (660, 1),
#   (661, 2),
#   (662, 1),
#   (663, 1),
#   (664, 1),
#   (665, 4),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 2),
#   (672, 5),
#   (673, 2),
#   (674, 8),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 3),
#   (681, 3),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 2),
#   (688, 6),
#   (689, 1),
#   (690, 1),
#   (691, 1),
#   (692, 1),
#   (693, 1),
#   (694, 2),
#   (695, 1),
#   (696, 1),
#   (697, 1),
#   (698, 1),
#   (699, 1),
#   (700, 1),
#   (701, 6),
#   (702, 1),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 4),
#   (708, 1),
#   (709, 1),
#   (710, 1),
#   (711, 1),
#   (712, 2),
#   (713, 2),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 2),
#   (721, 4),
#   (722, 4),
#   (723, 3),
#   (724, 2),
#   (725, 2),
#   (726, 1),
#   (727, 1),
#   (728, 1),
#   (729, 1),
#   (730, 3),
#   (731, 1),
#   (732, 2),
#   (733, 2),
#   (734, 2),
#   (735, 1),
#   (736, 2),
#   (737, 1),
#   (738, 1),
#   (739, 2),
#   (740, 1),
#   (741, 7),
#   (742, 1),
#   (743, 1),
#   (744, 3),
#   (745, 1),
#   (746, 1),
#   (747, 2),
#   (748, 1),
#   (749, 1),
#   (750, 1),
#   (751, 6),
#   (752, 2),
#   (753, 3),
#   (754, 1),
#   (755, 2),
#   (756, 1),
#   (757, 1),
#   (758, 1),
#   (759, 2),
#   (760, 1),
#   (761, 3),
#   (762, 1),
#   (763, 11),
#   (764, 1),
#   (765, 3),
#   (766, 2),
#   (767, 2),
#   (768, 1),
#   (769, 1),
#   (770, 1),
#   (771, 5),
#   (772, 2),
#   (773, 16),
#   (774, 2),
#   (775, 1),
#   (776, 1),
#   (777, 25),
#   (778, 1),
#   (779, 2),
#   (780, 4),
#   (781, 1),
#   (782, 1),
#   (783, 1),
#   (784, 1),
#   (785, 1),
#   (786, 1),
#   (787, 1),
#   (788, 1),
#   (789, 2),
#   (790, 3),
#   (791, 2),
#   (792, 1),
#   (793, 2),
#   (794, 1),
#   (795, 3),
#   (796, 1),
#   (797, 8),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 2),
#   (803, 1),
#   (804, 1)],
#  [(2, 2),
#   (5, 5),
#   (14, 7),
#   (15, 10),
#   (21, 3),
#   (31, 6),
#   (32, 17),
#   (37, 1),
#   (45, 13),
#   (46, 3),
#   (47, 4),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (53, 1),
#   (54, 1),
#   (57, 5),
#   (58, 1),
#   (62, 5),
#   (64, 4),
#   (69, 1),
#   (70, 4),
#   (73, 2),
#   (74, 2),
#   (83, 11),
#   (84, 1),
#   (85, 1),
#   (87, 1),
#   (89, 1),
#   (90, 1),
#   (91, 2),
#   (94, 2),
#   (95, 1),
#   (99, 6),
#   (101, 1),
#   (112, 1),
#   (116, 3),
#   (125, 1),
#   (128, 3),
#   (133, 3),
#   (138, 1),
#   (139, 1),
#   (142, 3),
#   (148, 5),
#   (150, 1),
#   (151, 5),
#   (159, 3),
#   (160, 1),
#   (165, 1),
#   (167, 1),
#   (168, 3),
#   (180, 3),
#   (182, 6),
#   (190, 5),
#   (192, 2),
#   (198, 5),
#   (201, 2),
#   (208, 1),
#   (211, 8),
#   (213, 1),
#   (233, 5),
#   (239, 4),
#   (242, 4),
#   (249, 1),
#   (251, 1),
#   (254, 1),
#   (255, 1),
#   (256, 15),
#   (257, 1),
#   (260, 4),
#   (262, 3),
#   (269, 1),
#   (273, 1),
#   (282, 3),
#   (284, 3),
#   (285, 1),
#   (286, 3),
#   (289, 19),
#   (290, 5),
#   (293, 2),
#   (294, 2),
#   (295, 2),
#   (296, 1),
#   (297, 6),
#   (299, 1),
#   (300, 12),
#   (301, 1),
#   (309, 3),
#   (310, 5),
#   (311, 1),
#   (312, 3),
#   (316, 3),
#   (317, 2),
#   (320, 2),
#   (323, 2),
#   (326, 7),
#   (327, 3),
#   (328, 1),
#   (330, 2),
#   (331, 1),
#   (335, 1),
#   (339, 42),
#   (343, 4),
#   (345, 4),
#   (347, 1),
#   (351, 1),
#   (352, 6),
#   (354, 1),
#   (362, 11),
#   (363, 5),
#   (366, 40),
#   (367, 19),
#   (369, 1),
#   (373, 2),
#   (375, 7),
#   (376, 1),
#   (379, 4),
#   (392, 1),
#   (400, 4),
#   (401, 1),
#   (405, 1),
#   (411, 7),
#   (413, 1),
#   (414, 6),
#   (416, 1),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (427, 4),
#   (431, 2),
#   (433, 1),
#   (435, 1),
#   (436, 1),
#   (439, 10),
#   (440, 5),
#   (441, 2),
#   (442, 11),
#   (448, 2),
#   (450, 25),
#   (453, 4),
#   (457, 1),
#   (458, 2),
#   (464, 6),
#   (469, 1),
#   (470, 2),
#   (472, 2),
#   (474, 5),
#   (475, 3),
#   (476, 1),
#   (477, 4),
#   (481, 2),
#   (482, 4),
#   (489, 2),
#   (496, 1),
#   (501, 1),
#   (504, 1),
#   (506, 2),
#   (507, 9),
#   (508, 4),
#   (509, 3),
#   (511, 2),
#   (512, 1),
#   (513, 1),
#   (515, 11),
#   (517, 3),
#   (518, 1),
#   (523, 2),
#   (528, 3),
#   (529, 10),
#   (532, 1),
#   (538, 1),
#   (540, 4),
#   (546, 1),
#   (556, 1),
#   (559, 3),
#   (563, 1),
#   (567, 8),
#   (569, 2),
#   (574, 1),
#   (579, 1),
#   (584, 1),
#   (586, 1),
#   (588, 2),
#   (599, 4),
#   (606, 4),
#   (608, 1),
#   (614, 1),
#   (615, 41),
#   (616, 2),
#   (618, 2),
#   (623, 1),
#   (627, 4),
#   (630, 1),
#   (631, 6),
#   (632, 2),
#   (634, 2),
#   (641, 2),
#   (642, 1),
#   (643, 1),
#   (646, 1),
#   (650, 3),
#   (653, 4),
#   (655, 4),
#   (657, 12),
#   (663, 2),
#   (664, 10),
#   (665, 2),
#   (666, 1),
#   (668, 3),
#   (669, 2),
#   (670, 1),
#   (671, 5),
#   (672, 3),
#   (677, 2),
#   (678, 1),
#   (687, 5),
#   (692, 3),
#   (694, 2),
#   (697, 2),
#   (702, 1),
#   (703, 16),
#   (704, 51),
#   (709, 2),
#   (711, 4),
#   (715, 4),
#   (716, 1),
#   (720, 4),
#   (722, 6),
#   (728, 1),
#   (730, 6),
#   (733, 1),
#   (744, 11),
#   (747, 21),
#   (748, 3),
#   (751, 1),
#   (753, 2),
#   (754, 1),
#   (756, 1),
#   (757, 6),
#   (760, 3),
#   (762, 3),
#   (766, 1),
#   (770, 1),
#   (773, 1),
#   (777, 31),
#   (780, 1),
#   (781, 7),
#   (782, 12),
#   (787, 2),
#   (789, 1),
#   (790, 4),
#   (791, 7),
#   (792, 1),
#   (793, 2),
#   (794, 2),
#   (797, 27),
#   (805, 1),
#   (806, 1),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 17),
#   (812, 1),
#   (813, 3),
#   (814, 1),
#   (815, 2),
#   (816, 2),
#   (817, 1),
#   (818, 1),
#   (819, 1),
#   (820, 5),
#   (821, 2),
#   (822, 3),
#   (823, 1),
#   (824, 2),
#   (825, 1),
#   (826, 1),
#   (827, 1),
#   (828, 2),
#   (829, 5),
#   (830, 1),
#   (831, 2),
#   (832, 1),
#   (833, 1),
#   (834, 1),
#   (835, 2),
#   (836, 1),
#   (837, 1),
#   (838, 1),
#   (839, 2),
#   (840, 2),
#   (841, 1),
#   (842, 5),
#   (843, 3),
#   (844, 2),
#   (845, 1),
#   (846, 1),
#   (847, 1),
#   (848, 1),
#   (849, 1),
#   (850, 1),
#   (851, 17),
#   (852, 1),
#   (853, 4),
#   (854, 10),
#   (855, 1),
#   (856, 1),
#   (857, 6),
#   (858, 1),
#   (859, 1),
#   (860, 1),
#   (861, 2),
#   (862, 1),
#   (863, 1),
#   (864, 1),
#   (865, 1),
#   (866, 1),
#   (867, 2),
#   (868, 2),
#   (869, 1),
#   (870, 2),
#   (871, 7),
#   (872, 1),
#   (873, 1),
#   (874, 2),
#   (875, 1),
#   (876, 1),
#   (877, 1),
#   (878, 1),
#   (879, 1),
#   (880, 1),
#   (881, 1),
#   (882, 1),
#   (883, 1),
#   (884, 1),
#   (885, 1),
#   (886, 1),
#   (887, 1),
#   (888, 2),
#   (889, 2),
#   (890, 1),
#   (891, 2),
#   (892, 1),
#   (893, 1),
#   (894, 2),
#   (895, 1),
#   (896, 1),
#   (897, 1),
#   (898, 3),
#   (899, 1),
#   (900, 1),
#   (901, 1),
#   (902, 2),
#   (903, 1),
#   (904, 2),
#   (905, 1),
#   (906, 1),
#   (907, 4),
#   (908, 3),
#   (909, 1),
#   (910, 1),
#   (911, 1),
#   (912, 2),
#   (913, 4),
#   (914, 8),
#   (915, 4),
#   (916, 1),
#   (917, 1),
#   (918, 2),
#   (919, 2),
#   (920, 1),
#   (921, 1),
#   (922, 1),
#   (923, 4),
#   (924, 1),
#   (925, 2),
#   (926, 1),
#   (927, 1),
#   (928, 1),
#   (929, 1),
#   (930, 5),
#   (931, 1),
#   (932, 6),
#   (933, 1),
#   (934, 1),
#   (935, 1),
#   (936, 1),
#   (937, 1),
#   (938, 1),
#   (939, 1),
#   (940, 2),
#   (941, 8),
#   (942, 1),
#   (943, 2),
#   (944, 1),
#   (945, 3),
#   (946, 11),
#   (947, 1),
#   (948, 1),
#   (949, 3),
#   (950, 1),
#   (951, 1),
#   (952, 1),
#   (953, 2),
#   (954, 1),
#   (955, 1),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 2),
#   (960, 3),
#   (961, 1),
#   (962, 2),
#   (963, 1),
#   (964, 4),
#   (965, 4),
#   (966, 1),
#   (967, 1),
#   (968, 1),
#   (969, 1),
#   (970, 2),
#   (971, 1),
#   (972, 3),
#   (973, 1),
#   (974, 1),
#   (975, 1),
#   (976, 1),
#   (977, 1),
#   (978, 2),
#   (979, 1),
#   (980, 7),
#   (981, 1),
#   (982, 2),
#   (983, 16),
#   (984, 1),
#   (985, 7),
#   (986, 1),
#   (987, 1),
#   (988, 1),
#   (989, 1),
#   (990, 4),
#   (991, 1),
#   (992, 1),
#   (993, 6),
#   (994, 27),
#   (995, 2),
#   (996, 1),
#   (997, 5),
#   (998, 1),
#   (999, 1),
#   (1000, 1),
#   (1001, 7),
#   (1002, 2),
#   (1003, 1),
#   (1004, 1),
#   (1005, 3),
#   (1006, 1),
#   (1007, 1),
#   (1008, 1),
#   (1009, 1),
#   (1010, 1),
#   (1011, 9),
#   (1012, 20),
#   (1013, 6),
#   (1014, 5),
#   (1015, 1),
#   (1016, 1),
#   (1017, 6),
#   (1018, 1),
#   (1019, 1),
#   (1020, 1),
#   (1021, 1),
#   (1022, 3),
#   (1023, 1),
#   (1024, 2),
#   (1025, 2),
#   (1026, 3),
#   (1027, 1),
#   (1028, 4),
#   (1029, 2),
#   (1030, 1),
#   (1031, 2),
#   (1032, 2),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 1),
#   (1037, 5),
#   (1038, 1),
#   (1039, 2),
#   (1040, 1),
#   (1041, 4),
#   (1042, 6),
#   (1043, 3),
#   (1044, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 2),
#   (1049, 9),
#   (1050, 2),
#   (1051, 1),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1),
#   (1055, 2),
#   (1056, 10),
#   (1057, 7),
#   (1058, 1),
#   (1059, 5),
#   (1060, 8),
#   (1061, 1),
#   (1062, 2),
#   (1063, 2),
#   (1064, 8),
#   (1065, 1),
#   (1066, 1),
#   (1067, 9),
#   (1068, 1),
#   (1069, 1),
#   (1070, 6),
#   (1071, 1),
#   (1072, 1),
#   (1073, 1),
#   (1074, 3),
#   (1075, 3),
#   (1076, 3),
#   (1077, 3),
#   (1078, 2),
#   (1079, 1),
#   (1080, 1),
#   (1081, 1),
#   (1082, 1),
#   (1083, 1),
#   (1084, 1),
#   (1085, 6),
#   (1086, 4),
#   (1087, 1),
#   (1088, 1),
#   (1089, 1),
#   (1090, 1),
#   (1091, 1),
#   (1092, 3),
#   (1093, 1),
#   (1094, 3),
#   (1095, 1),
#   (1096, 1),
#   (1097, 1),
#   (1098, 1),
#   (1099, 1),
#   (1100, 1),
#   (1101, 1),
#   (1102, 1),
#   (1103, 1),
#   (1104, 5),
#   (1105, 9),
#   (1106, 1),
#   (1107, 24),
#   (1108, 3),
#   (1109, 2),
#   (1110, 2),
#   (1111, 2),
#   (1112, 1),
#   (1113, 1),
#   (1114, 2),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 1),
#   (1119, 7),
#   (1120, 1),
#   (1121, 1),
#   (1122, 1),
#   (1123, 1),
#   (1124, 1),
#   (1125, 1),
#   (1126, 1),
#   (1127, 1),
#   (1128, 1),
#   (1129, 6),
#   (1130, 2),
#   (1131, 1),
#   (1132, 2),
#   (1133, 1),
#   (1134, 1),
#   (1135, 1),
#   (1136, 1),
#   (1137, 1),
#   (1138, 2),
#   (1139, 1),
#   (1140, 1),
#   (1141, 13),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 20),
#   (1148, 1),
#   (1149, 1),
#   (1150, 1),
#   (1151, 2),
#   (1152, 1),
#   (1153, 1),
#   (1154, 4),
#   (1155, 1),
#   (1156, 1),
#   (1157, 1),
#   (1158, 1),
#   (1159, 17),
#   (1160, 1),
#   (1161, 1),
#   (1162, 1),
#   (1163, 1),
#   (1164, 3),
#   (1165, 2),
#   (1166, 1),
#   (1167, 2),
#   (1168, 10),
#   (1169, 5),
#   (1170, 3),
#   (1171, 1),
#   (1172, 1),
#   (1173, 1),
#   (1174, 1),
#   (1175, 1),
#   (1176, 1),
#   (1177, 2),
#   (1178, 1),
#   (1179, 2),
#   (1180, 1),
#   (1181, 1),
#   (1182, 1),
#   (1183, 3),
#   (1184, 2),
#   (1185, 2),
#   (1186, 3),
#   (1187, 1),
#   (1188, 1),
#   (1189, 2),
#   (1190, 1),
#   (1191, 1),
#   (1192, 1),
#   (1193, 1),
#   (1194, 1),
#   (1195, 2),
#   (1196, 6),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1),
#   (1200, 1),
#   (1201, 1),
#   (1202, 2),
#   (1203, 1),
#   (1204, 1),
#   (1205, 2),
#   (1206, 1),
#   (1207, 2),
#   (1208, 1),
#   (1209, 1),
#   (1210, 1),
#   (1211, 2),
#   (1212, 1),
#   (1213, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1),
#   (1217, 14),
#   (1218, 1),
#   (1219, 2),
#   (1220, 1),
#   (1221, 2),
#   (1222, 4),
#   (1223, 1),
#   (1224, 3),
#   (1225, 1),
#   (1226, 1),
#   (1227, 2),
#   (1228, 2),
#   (1229, 1),
#   (1230, 1),
#   (1231, 1),
#   (1232, 1),
#   (1233, 1),
#   (1234, 2),
#   (1235, 1),
#   (1236, 1),
#   (1237, 1),
#   (1238, 1),
#   (1239, 1),
#   (1240, 6),
#   (1241, 36),
#   (1242, 1),
#   (1243, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 3),
#   (1247, 3),
#   (1248, 13),
#   (1249, 2),
#   (1250, 1),
#   (1251, 1),
#   (1252, 1),
#   (1253, 1),
#   (1254, 1),
#   (1255, 10),
#   (1256, 3),
#   (1257, 1),
#   (1258, 2),
#   (1259, 1),
#   (1260, 2),
#   (1261, 2),
#   (1262, 3),
#   (1263, 3),
#   (1264, 1),
#   (1265, 1),
#   (1266, 1),
#   (1267, 1),
#   (1268, 1),
#   (1269, 2),
#   (1270, 1),
#   (1271, 1),
#   (1272, 2),
#   (1273, 1),
#   (1274, 2),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 2),
#   (1281, 1),
#   (1282, 3),
#   (1283, 1),
#   (1284, 5),
#   (1285, 1),
#   (1286, 6),
#   (1287, 1),
#   (1288, 1),
#   (1289, 1),
#   (1290, 1),
#   (1291, 1),
#   (1292, 1),
#   (1293, 1),
#   (1294, 1),
#   (1295, 2),
#   (1296, 1),
#   (1297, 1),
#   (1298, 12),
#   (1299, 7),
#   (1300, 3),
#   (1301, 5),
#   (1302, 1),
#   (1303, 4),
#   (1304, 1),
#   (1305, 1),
#   (1306, 1),
#   (1307, 1),
#   (1308, 1),
#   (1309, 1),
#   (1310, 1),
#   (1311, 4),
#   (1312, 1),
#   (1313, 4),
#   (1314, 3),
#   (1315, 1),
#   (1316, 1),
#   (1317, 1),
#   (1318, 1),
#   (1319, 1),
#   (1320, 2),
#   (1321, 2),
#   (1322, 2),
#   (1323, 6),
#   (1324, 1),
#   (1325, 1),
#   (1326, 1),
#   (1327, 2),
#   (1328, 1),
#   (1329, 7),
#   (1330, 1),
#   (1331, 1),
#   (1332, 1),
#   (1333, 1),
#   (1334, 2),
#   (1335, 2),
#   (1336, 2),
#   (1337, 1),
#   (1338, 4),
#   (1339, 1),
#   (1340, 2),
#   (1341, 9),
#   (1342, 1),
#   (1343, 1),
#   (1344, 2),
#   (1345, 1),
#   (1346, 1),
#   (1347, 1),
#   (1348, 1),
#   (1349, 2),
#   (1350, 3),
#   (1351, 1),
#   (1352, 1),
#   (1353, 1),
#   (1354, 1),
#   (1355, 1),
#   (1356, 1),
#   (1357, 1),
#   (1358, 5),
#   (1359, 1),
#   (1360, 1),
#   (1361, 2),
#   (1362, 1),
#   (1363, 1),
#   (1364, 1),
#   (1365, 1),
#   (1366, 3),
#   (1367, 3),
#   (1368, 2),
#   (1369, 3),
#   (1370, 7),
#   (1371, 1),
#   (1372, 1),
#   (1373, 5),
#   (1374, 15),
#   (1375, 2),
#   (1376, 6),
#   (1377, 1),
#   (1378, 1),
#   (1379, 11),
#   (1380, 1),
#   (1381, 1),
#   (1382, 43),
#   (1383, 1),
#   (1384, 1),
#   (1385, 1),
#   (1386, 1),
#   (1387, 1),
#   (1388, 1),
#   (1389, 1),
#   (1390, 1),
#   (1391, 1),
#   (1392, 1),
#   (1393, 1),
#   (1394, 1),
#   (1395, 2),
#   (1396, 2),
#   (1397, 1),
#   (1398, 1),
#   (1399, 13),
#   (1400, 1),
#   (1401, 6),
#   (1402, 10),
#   (1403, 1),
#   (1404, 1),
#   (1405, 2),
#   (1406, 1),
#   (1407, 2),
#   (1408, 1),
#   (1409, 1),
#   (1410, 1),
#   (1411, 1),
#   (1412, 4),
#   (1413, 2),
#   (1414, 10),
#   (1415, 2),
#   (1416, 2),
#   (1417, 1),
#   (1418, 2),
#   (1419, 4),
#   (1420, 3),
#   (1421, 1),
#   (1422, 1),
#   (1423, 1),
#   (1424, 2),
#   (1425, 1),
#   (1426, 4),
#   (1427, 2),
#   (1428, 1),
#   (1429, 2),
#   (1430, 98),
#   (1431, 1),
#   (1432, 9),
#   (1433, 1),
#   (1434, 1),
#   (1435, 1),
#   (1436, 2),
#   (1437, 3),
#   (1438, 1),
#   (1439, 1),
#   (1440, 2),
#   (1441, 1),
#   (1442, 1),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 2),
#   (1447, 1),
#   (1448, 1),
#   (1449, 1),
#   (1450, 1),
#   (1451, 3),
#   (1452, 1),
#   (1453, 1),
#   (1454, 2),
#   (1455, 1),
#   (1456, 1),
#   (1457, 2),
#   (1458, 2),
#   (1459, 1),
#   (1460, 7),
#   (1461, 10),
#   (1462, 2),
#   (1463, 1),
#   (1464, 4),
#   (1465, 5),
#   (1466, 1),
#   (1467, 3),
#   (1468, 2),
#   (1469, 1),
#   (1470, 69),
#   (1471, 9),
#   (1472, 1),
#   (1473, 2),
#   (1474, 2),
#   (1475, 1),
#   (1476, 3),
#   (1477, 7),
#   (1478, 1),
#   (1479, 7),
#   (1480, 2),
#   (1481, 1),
#   (1482, 1),
#   (1483, 1),
#   (1484, 1),
#   (1485, 1),
#   (1486, 1),
#   (1487, 1),
#   (1488, 1),
#   (1489, 1),
#   (1490, 1),
#   (1491, 1),
#   (1492, 1),
#   (1493, 1),
#   (1494, 1),
#   (1495, 1),
#   (1496, 1),
#   (1497, 1),
#   (1498, 1),
#   (1499, 2),
#   (1500, 1),
#   (1501, 2),
#   (1502, 1),
#   (1503, 1),
#   (1504, 1),
#   (1505, 1),
#   (1506, 1),
#   (1507, 1),
#   (1508, 1),
#   (1509, 1),
#   (1510, 1),
#   (1511, 1),
#   (1512, 1),
#   (1513, 6),
#   (1514, 1),
#   (1515, 1),
#   (1516, 1),
#   (1517, 1),
#   (1518, 1),
#   (1519, 1),
#   (1520, 1),
#   (1521, 2),
#   (1522, 1),
#   (1523, 2),
#   (1524, 22),
#   (1525, 1),
#   (1526, 1),
#   (1527, 1),
#   (1528, 1),
#   (1529, 1),
#   (1530, 1),
#   (1531, 1),
#   (1532, 2),
#   (1533, 1),
#   (1534, 2),
#   (1535, 1),
#   (1536, 1),
#   (1537, 1),
#   (1538, 1),
#   (1539, 5),
#   (1540, 2),
#   (1541, 92),
#   (1542, 1),
#   (1543, 1),
#   (1544, 1),
#   (1545, 9),
#   (1546, 2),
#   (1547, 2),
#   (1548, 3),
#   ...],
#  [(6, 1),
#   (30, 1),
#   (32, 1),
#   (37, 2),
#   (47, 2),
#   (64, 2),
#   (72, 1),
#   (74, 1),
#   (83, 2),
#   (84, 2),
#   (92, 7),
#   (95, 1),
#   (116, 1),
#   (129, 1),
#   (133, 1),
#   (134, 1),
#   (145, 1),
#   (151, 3),
#   (159, 3),
#   (161, 2),
#   (165, 1),
#   (202, 3),
#   (210, 3),
#   (211, 2),
#   (213, 1),
#   (214, 3),
#   (220, 2),
#   (221, 1),
#   (233, 1),
#   (264, 1),
#   (271, 1),
#   (279, 1),
#   (280, 1),
#   (289, 1),
#   (295, 1),
#   (301, 1),
#   (309, 1),
#   (312, 1),
#   (339, 3),
#   (343, 2),
#   (359, 3),
#   (363, 3),
#   (364, 1),
#   (375, 1),
#   (399, 5),
#   (402, 1),
#   (403, 2),
#   (411, 3),
#   (415, 1),
#   (416, 1),
#   (427, 1),
#   (431, 1),
#   (435, 4),
#   (448, 1),
#   (469, 6),
#   (482, 6),
#   (502, 1),
#   (511, 1),
#   (515, 1),
#   (517, 1),
#   (527, 1),
#   (529, 1),
#   (540, 5),
#   (550, 1),
#   (551, 1),
#   (562, 1),
#   (563, 1),
#   (586, 1),
#   (588, 1),
#   (608, 1),
#   (620, 1),
#   (631, 2),
#   (632, 2),
#   (649, 1),
#   (657, 1),
#   (661, 1),
#   (668, 1),
#   (675, 1),
#   (687, 4),
#   (704, 4),
#   (711, 2),
#   (718, 1),
#   (723, 1),
#   (727, 5),
#   (728, 1),
#   (744, 1),
#   (746, 1),
#   (749, 1),
#   (756, 1),
#   (757, 15),
#   (758, 1),
#   (761, 2),
#   (762, 1),
#   (777, 3),
#   (781, 2),
#   (791, 1),
#   (793, 2),
#   (797, 2),
#   (840, 1),
#   (847, 2),
#   (855, 2),
#   (873, 1),
#   (962, 1),
#   (972, 1),
#   (983, 1),
#   (985, 7),
#   (987, 1),
#   (1043, 1),
#   (1056, 1),
#   (1058, 1),
#   (1059, 1),
#   (1060, 1),
#   (1067, 1),
#   (1070, 4),
#   (1072, 1),
#   (1077, 1),
#   (1094, 1),
#   (1109, 1),
#   (1125, 80),
#   (1126, 1),
#   (1135, 1),
#   (1152, 1),
#   (1155, 1),
#   (1157, 4),
#   (1169, 1),
#   (1170, 2),
#   (1178, 1),
#   (1186, 1),
#   (1197, 1),
#   (1202, 1),
#   (1207, 1),
#   (1217, 1),
#   (1226, 1),
#   (1232, 1),
#   (1234, 3),
#   (1241, 1),
#   (1255, 1),
#   (1275, 1),
#   (1282, 1),
#   (1294, 1),
#   (1301, 8),
#   (1327, 1),
#   (1331, 4),
#   (1332, 1),
#   (1334, 1),
#   (1366, 3),
#   (1370, 1),
#   (1374, 1),
#   (1400, 3),
#   (1416, 1),
#   (1419, 1),
#   (1427, 1),
#   (1445, 1),
#   (1446, 1),
#   (1451, 1),
#   (1461, 2),
#   (1464, 5),
#   (1479, 1),
#   (1480, 1),
#   (1481, 2),
#   (1483, 1),
#   (1522, 2),
#   (1538, 1),
#   (1548, 4),
#   (1570, 3),
#   (1582, 8),
#   (1585, 2),
#   (1588, 1),
#   (1596, 1),
#   (1609, 1),
#   (1617, 1),
#   (1629, 2),
#   (1656, 4),
#   (1664, 3),
#   (1689, 1),
#   (1699, 1),
#   (1712, 1),
#   (1722, 1),
#   (1738, 1),
#   (1765, 1),
#   (1826, 3),
#   (1828, 2),
#   (1829, 1),
#   (1831, 2),
#   (1833, 4),
#   (1842, 4),
#   (1859, 2),
#   (1894, 1),
#   (1903, 1),
#   (1910, 2),
#   (1915, 2),
#   (1920, 1),
#   (1931, 1),
#   (1962, 1),
#   (1990, 1),
#   (1996, 45),
#   (1997, 3),
#   (2007, 2),
#   (2056, 1),
#   (2063, 1),
#   (2099, 1),
#   (2127, 1),
#   (2128, 1),
#   (2148, 1),
#   (2159, 1),
#   (2164, 2),
#   (2171, 1),
#   (2178, 1),
#   (2198, 1),
#   (2200, 3),
#   (2208, 2),
#   (2251, 1),
#   (2253, 1),
#   (2258, 1),
#   (2265, 2),
#   (2266, 1),
#   (2267, 1),
#   (2268, 1),
#   (2269, 1),
#   (2270, 1),
#   (2271, 1),
#   (2272, 1),
#   (2273, 1),
#   (2274, 1),
#   (2275, 7),
#   (2276, 1),
#   (2277, 1),
#   (2278, 1),
#   (2279, 1),
#   (2280, 2),
#   (2281, 2),
#   (2282, 1),
#   (2283, 2),
#   (2284, 1),
#   (2285, 1),
#   (2286, 1),
#   (2287, 1),
#   (2288, 1),
#   (2289, 2),
#   (2290, 1),
#   (2291, 1),
#   (2292, 1),
#   (2293, 1),
#   (2294, 1),
#   (2295, 1),
#   (2296, 1),
#   (2297, 1),
#   (2298, 3),
#   (2299, 1),
#   (2300, 2),
#   (2301, 1),
#   (2302, 1),
#   (2303, 2),
#   (2304, 1),
#   (2305, 3),
#   (2306, 1),
#   (2307, 2),
#   (2308, 1),
#   (2309, 1),
#   (2310, 2),
#   (2311, 2),
#   (2312, 3),
#   (2313, 3),
#   (2314, 1),
#   (2315, 1),
#   (2316, 1),
#   (2317, 1),
#   (2318, 3),
#   (2319, 2),
#   (2320, 1),
#   (2321, 1),
#   (2322, 2),
#   (2323, 1),
#   (2324, 1),
#   (2325, 2),
#   (2326, 1),
#   (2327, 1),
#   (2328, 1),
#   (2329, 1),
#   (2330, 1),
#   (2331, 1),
#   (2332, 1),
#   (2333, 1),
#   (2334, 1),
#   (2335, 1),
#   (2336, 1),
#   (2337, 1),
#   (2338, 1),
#   (2339, 1),
#   (2340, 2),
#   (2341, 1),
#   (2342, 2),
#   (2343, 1),
#   (2344, 1),
#   (2345, 1),
#   (2346, 1),
#   (2347, 1),
#   (2348, 1),
#   (2349, 1),
#   (2350, 1),
#   (2351, 1),
#   (2352, 1),
#   (2353, 1),
#   (2354, 2),
#   (2355, 1),
#   (2356, 1),
#   (2357, 1),
#   (2358, 2),
#   (2359, 1),
#   (2360, 1),
#   (2361, 1),
#   (2362, 1),
#   (2363, 1),
#   (2364, 1),
#   (2365, 1),
#   (2366, 1),
#   (2367, 1),
#   (2368, 1),
#   (2369, 1),
#   (2370, 1),
#   (2371, 1),
#   (2372, 2),
#   (2373, 1),
#   (2374, 1),
#   (2375, 1),
#   (2376, 1),
#   (2377, 1),
#   (2378, 1),
#   (2379, 1),
#   (2380, 1),
#   (2381, 1),
#   (2382, 1),
#   (2383, 1),
#   (2384, 1),
#   (2385, 2),
#   (2386, 1),
#   (2387, 1),
#   (2388, 2),
#   (2389, 2),
#   (2390, 1),
#   (2391, 1),
#   (2392, 1),
#   (2393, 1),
#   (2394, 1),
#   (2395, 1),
#   (2396, 1),
#   (2397, 7),
#   (2398, 1),
#   (2399, 1),
#   (2400, 1),
#   (2401, 1),
#   (2402, 1),
#   (2403, 2),
#   (2404, 1),
#   (2405, 3),
#   (2406, 1),
#   (2407, 1),
#   (2408, 1),
#   (2409, 1),
#   (2410, 1),
#   (2411, 1),
#   (2412, 1),
#   (2413, 1),
#   (2414, 1),
#   (2415, 1),
#   (2416, 1),
#   (2417, 1),
#   (2418, 2),
#   (2419, 1),
#   (2420, 1),
#   (2421, 1),
#   (2422, 1),
#   (2423, 1),
#   (2424, 2),
#   (2425, 1),
#   (2426, 1),
#   (2427, 1),
#   (2428, 1),
#   (2429, 1),
#   (2430, 1),
#   (2431, 1),
#   (2432, 2),
#   (2433, 1),
#   (2434, 1),
#   (2435, 1),
#   (2436, 1),
#   (2437, 4),
#   (2438, 1),
#   (2439, 2),
#   (2440, 1),
#   (2441, 1),
#   (2442, 2),
#   (2443, 2),
#   (2444, 1),
#   (2445, 1),
#   (2446, 1),
#   (2447, 1),
#   (2448, 1),
#   (2449, 2),
#   (2450, 2),
#   (2451, 1),
#   (2452, 1),
#   (2453, 1),
#   (2454, 2),
#   (2455, 1),
#   (2456, 1),
#   (2457, 1),
#   (2458, 1),
#   (2459, 1),
#   (2460, 1),
#   (2461, 2),
#   (2462, 6),
#   (2463, 1),
#   (2464, 1),
#   (2465, 18),
#   (2466, 4),
#   (2467, 3),
#   (2468, 1),
#   (2469, 2),
#   (2470, 1),
#   (2471, 1),
#   (2472, 1),
#   (2473, 1),
#   (2474, 1),
#   (2475, 1),
#   (2476, 1),
#   (2477, 1),
#   (2478, 1),
#   (2479, 1),
#   (2480, 1),
#   (2481, 1),
#   (2482, 7),
#   (2483, 1),
#   (2484, 2),
#   (2485, 1),
#   (2486, 1),
#   (2487, 1),
#   (2488, 1),
#   (2489, 2),
#   (2490, 1),
#   (2491, 1),
#   (2492, 1),
#   (2493, 1),
#   (2494, 1),
#   (2495, 1),
#   (2496, 1),
#   (2497, 2),
#   (2498, 1),
#   (2499, 1),
#   (2500, 1),
#   (2501, 1),
#   (2502, 7),
#   (2503, 1),
#   (2504, 1),
#   (2505, 1),
#   (2506, 2),
#   (2507, 1),
#   (2508, 1),
#   (2509, 1),
#   (2510, 2),
#   (2511, 1),
#   (2512, 1)],
#  [(1, 2),
#   (3, 12),
#   (5, 3),
#   (6, 1),
#   (13, 1),
#   (14, 2),
#   (15, 1),
#   (16, 7),
#   (22, 10),
#   (31, 2),
#   (32, 29),
#   (36, 1),
#   (37, 5),
#   (38, 9),
#   (44, 5),
#   (47, 4),
#   (50, 4),
#   (52, 1),
#   (54, 7),
#   (63, 2),
#   (64, 1),
#   (66, 1),
#   (67, 1),
#   (70, 6),
#   (71, 9),
#   (74, 2),
#   (79, 1),
#   (83, 15),
#   (85, 1),
#   (91, 1),
#   (96, 1),
#   (116, 5),
#   (121, 14),
#   (125, 3),
#   (126, 1),
#   (128, 4),
#   (131, 2),
#   (133, 1),
#   (138, 5),
#   (139, 15),
#   (140, 12),
#   (141, 1),
#   (142, 3),
#   (145, 1),
#   (147, 1),
#   (148, 3),
#   (150, 2),
#   (151, 1),
#   (154, 2),
#   (155, 1),
#   (158, 1),
#   (159, 3),
#   (160, 2),
#   (162, 10),
#   (165, 2),
#   (168, 1),
#   (182, 7),
#   (186, 1),
#   (198, 11),
#   (201, 15),
#   (210, 2),
#   (213, 4),
#   (221, 1),
#   (233, 2),
#   (240, 10),
#   (242, 3),
#   (251, 1),
#   (254, 1),
#   (255, 3),
#   (256, 2),
#   (259, 1),
#   (265, 1),
#   (269, 1),
#   (279, 3),
#   (282, 3),
#   (284, 1),
#   (289, 16),
#   (290, 1),
#   (295, 3),
#   (299, 9),
#   (300, 5),
#   (303, 1),
#   (311, 1),
#   (312, 1),
#   (317, 1),
#   (320, 2),
#   (323, 3),
#   (326, 4),
#   (327, 1),
#   (331, 1),
#   (339, 36),
#   (343, 2),
#   (345, 1),
#   (351, 1),
#   (358, 1),
#   (359, 5),
#   (361, 2),
#   (362, 15),
#   (363, 16),
#   (367, 1),
#   (368, 5),
#   (375, 4),
#   (377, 4),
#   (378, 1),
#   (379, 9),
#   (389, 3),
#   (390, 1),
#   (395, 1),
#   (401, 1),
#   (402, 6),
#   (404, 12),
#   (414, 3),
#   (416, 1),
#   (418, 1),
#   (420, 2),
#   (421, 1),
#   (427, 1),
#   (431, 2),
#   (435, 7),
#   (436, 9),
#   (440, 39),
#   (442, 1),
#   (449, 1),
#   (450, 3),
#   (453, 1),
#   (460, 1),
#   (469, 4),
#   (470, 2),
#   (473, 1),
#   (475, 1),
#   (477, 2),
#   (478, 1),
#   (482, 12),
#   (484, 1),
#   (486, 1),
#   (496, 11),
#   (498, 1),
#   (499, 1),
#   (500, 4),
#   (501, 7),
#   (502, 15),
#   (508, 1),
#   (509, 4),
#   (510, 4),
#   (511, 1),
#   (512, 5),
#   (515, 12),
#   (520, 1),
#   (523, 1),
#   (527, 1),
#   (529, 3),
#   (532, 40),
#   (534, 11),
#   (542, 2),
#   (548, 3),
#   (554, 12),
#   (558, 4),
#   (562, 4),
#   (563, 2),
#   (564, 1),
#   (565, 3),
#   (569, 5),
#   (571, 3),
#   (586, 1),
#   (588, 2),
#   (589, 3),
#   (590, 1),
#   (592, 3),
#   (593, 2),
#   (601, 3),
#   (608, 2),
#   (615, 2),
#   (616, 1),
#   (618, 3),
#   (620, 1),
#   (621, 2),
#   (623, 1),
#   (626, 1),
#   (627, 3),
#   (629, 3),
#   (631, 3),
#   (632, 1),
#   (633, 4),
#   (634, 12),
#   (642, 4),
#   (643, 8),
#   (645, 2),
#   (646, 5),
#   (648, 1),
#   (649, 1),
#   (650, 4),
#   (653, 1),
#   (655, 5),
#   (657, 1),
#   (658, 1),
#   (661, 1),
#   (663, 1),
#   (664, 2),
#   (665, 1),
#   (671, 1),
#   (672, 11),
#   (680, 1),
#   (687, 7),
#   (692, 2),
#   (694, 3),
#   (700, 1),
#   (709, 2),
#   (711, 8),
#   (716, 1),
#   (718, 4),
#   (719, 4),
#   (722, 15),
#   (730, 1),
#   (733, 1),
#   (736, 3),
#   (738, 1),
#   (744, 15),
#   (746, 2),
#   (747, 16),
#   (748, 2),
#   (751, 12),
#   (753, 1),
#   (754, 3),
#   (756, 15),
#   (757, 7),
#   (758, 1),
#   (759, 10),
#   (762, 2),
#   (765, 4),
#   (773, 2),
#   (777, 31),
#   (781, 3),
#   (784, 3),
#   (789, 5),
#   (791, 13),
#   (793, 2),
#   (797, 12),
#   (801, 6),
#   (811, 2),
#   (813, 4),
#   (822, 4),
#   (823, 2),
#   (824, 2),
#   (828, 5),
#   (832, 1),
#   (838, 1),
#   (840, 1),
#   (842, 1),
#   (843, 1),
#   (850, 1),
#   (854, 5),
#   (858, 1),
#   (859, 2),
#   (864, 6),
#   (866, 3),
#   (873, 2),
#   (884, 1),
#   (908, 3),
#   (912, 1),
#   (914, 1),
#   (916, 1),
#   (923, 1),
#   (938, 2),
#   (939, 1),
#   (940, 2),
#   (964, 8),
#   (985, 1),
#   (987, 1),
#   (992, 1),
#   (995, 2),
#   (1001, 3),
#   (1004, 1),
#   (1005, 38),
#   (1010, 14),
#   (1011, 14),
#   (1012, 4),
#   (1037, 4),
#   (1046, 1),
#   (1056, 1),
#   (1057, 6),
#   (1058, 2),
#   (1059, 1),
#   (1060, 2),
#   (1065, 1),
#   (1071, 1),
#   (1075, 1),
#   (1078, 1),
#   (1088, 5),
#   (1089, 1),
#   (1091, 1),
#   (1094, 6),
#   (1106, 1),
#   (1107, 1),
#   (1112, 2),
#   (1118, 1),
#   (1125, 9),
#   (1127, 3),
#   (1138, 1),
#   (1155, 1),
#   (1157, 2),
#   (1158, 3),
#   (1159, 6),
#   (1165, 2),
#   (1167, 1),
#   (1168, 2),
#   (1177, 2),
#   (1182, 3),
#   (1187, 2),
#   (1189, 2),
#   (1190, 1),
#   (1195, 1),
#   (1197, 10),
#   (1202, 2),
#   (1205, 2),
#   (1206, 3),
#   (1207, 10),
#   (1211, 2),
#   (1213, 1),
#   (1225, 5),
#   (1226, 1),
#   (1233, 1),
#   (1234, 2),
#   (1242, 1),
#   (1245, 1),
#   (1250, 5),
#   (1255, 2),
#   (1257, 2),
#   (1273, 2),
#   (1284, 2),
#   (1290, 1),
#   (1300, 3),
#   (1309, 1),
#   (1314, 2),
#   (1315, 2),
#   (1317, 5),
#   (1332, 1),
#   (1336, 2),
#   (1345, 1),
#   (1347, 1),
#   (1352, 1),
#   (1353, 1),
#   (1355, 1),
#   (1358, 4),
#   (1361, 1),
#   (1373, 1),
#   (1374, 9),
#   (1378, 5),
#   (1400, 9),
#   (1401, 6),
#   (1405, 2),
#   (1412, 16),
#   (1413, 2),
#   (1416, 5),
#   (1419, 12),
#   (1427, 4),
#   (1440, 2),
#   (1445, 2),
#   (1446, 2),
#   (1452, 1),
#   (1457, 11),
#   (1458, 2),
#   (1461, 1),
#   (1464, 2),
#   (1468, 1),
#   (1470, 9),
#   (1471, 1),
#   (1484, 1),
#   (1493, 1),
#   (1494, 2),
#   (1495, 1),
#   (1496, 3),
#   (1498, 1),
#   (1522, 2),
#   (1524, 1),
#   (1538, 1),
#   (1549, 4),
#   (1562, 2),
#   (1563, 5),
#   (1564, 1),
#   (1570, 4),
#   (1578, 3),
#   (1585, 8),
#   (1591, 3),
#   (1593, 2),
#   (1596, 7),
#   (1599, 4),
#   (1606, 1),
#   (1607, 1),
#   (1609, 5),
#   (1616, 1),
#   (1617, 3),
#   (1625, 4),
#   (1635, 1),
#   (1638, 12),
#   (1639, 1),
#   (1643, 1),
#   (1653, 5),
#   (1657, 1),
#   (1658, 2),
#   (1664, 8),
#   (1667, 8),
#   (1678, 1),
#   (1681, 2),
#   (1683, 1),
#   (1689, 16),
#   (1693, 1),
#   (1708, 1),
#   (1709, 1),
#   (1710, 5),
#   (1712, 1),
#   (1718, 1),
#   (1727, 3),
#   (1728, 1),
#   (1731, 2),
#   (1738, 1),
#   (1741, 2),
#   (1764, 1),
#   (1768, 1),
#   (1772, 6),
#   (1788, 2),
#   (1791, 1),
#   (1793, 1),
#   (1797, 1),
#   (1798, 1),
#   (1799, 1),
#   (1803, 3),
#   (1815, 1),
#   (1816, 1),
#   (1818, 2),
#   (1819, 1),
#   (1826, 2),
#   (1828, 3),
#   (1831, 1),
#   (1834, 3),
#   (1838, 1),
#   (1840, 1),
#   (1842, 2),
#   (1844, 11),
#   (1845, 2),
#   (1856, 2),
#   (1859, 2),
#   (1877, 1),
#   (1878, 5),
#   (1885, 20),
#   (1891, 1),
#   (1895, 1),
#   (1898, 6),
#   (1899, 9),
#   (1902, 1),
#   (1903, 1),
#   (1910, 9),
#   (1914, 1),
#   (1915, 11),
#   (1919, 1),
#   (1920, 17),
#   (1928, 5),
#   (1930, 1),
#   (1931, 1),
#   (1936, 15),
#   (1958, 1),
#   (1962, 1),
#   (1973, 2),
#   (1990, 1),
#   (1992, 1),
#   (1997, 2),
#   (1999, 2),
#   (2013, 1),
#   (2023, 3),
#   (2028, 1),
#   (2040, 4),
#   (2043, 1),
#   (2046, 6),
#   (2052, 1),
#   (2055, 2),
#   (2060, 9),
#   (2063, 2),
#   (2070, 7),
#   (2083, 4),
#   (2085, 2),
#   (2086, 1),
#   (2089, 1),
#   (2090, 1),
#   (2091, 3),
#   (2094, 1),
#   (2098, 2),
#   (2101, 24),
#   (2127, 2),
#   (2131, 3),
#   (2132, 1),
#   (2140, 2),
#   (2154, 10),
#   (2164, 2),
#   (2165, 1),
#   (2166, 1),
#   (2171, 1),
#   (2180, 1),
#   (2182, 2),
#   (2190, 6),
#   (2197, 1),
#   (2200, 6),
#   (2203, 2),
#   (2208, 2),
#   (2210, 1),
#   (2213, 1),
#   (2228, 6),
#   (2230, 2),
#   (2241, 5),
#   (2243, 7),
#   (2253, 11),
#   (2255, 6),
#   (2256, 1),
#   (2265, 4),
#   (2269, 1),
#   (2272, 1),
#   (2275, 6),
#   (2285, 1),
#   (2288, 1),
#   (2298, 1),
#   (2311, 1),
#   (2317, 1),
#   (2318, 1),
#   (2324, 1),
#   (2334, 1),
#   (2336, 1),
#   (2340, 1),
#   (2354, 3),
#   (2362, 1),
#   (2374, 3),
#   (2378, 4),
#   (2391, 3),
#   (2398, 1),
#   (2403, 4),
#   (2414, 1),
#   (2417, 1),
#   (2418, 10),
#   (2419, 3),
#   (2432, 1),
#   (2436, 1),
#   (2445, 4),
#   (2447, 5),
#   (2454, 2),
#   (2465, 2),
#   (2469, 1),
#   (2470, 2),
#   (2471, 5),
#   (2474, 3),
#   (2480, 1),
#   (2482, 2),
#   (2484, 1),
#   (2485, 2),
#   (2487, 1),
#   (2498, 1),
#   (2503, 1),
#   (2508, 2),
#   (2513, 1),
#   (2514, 1),
#   (2515, 1),
#   (2516, 1),
#   (2517, 1),
#   (2518, 1),
#   (2519, 2),
#   (2520, 10),
#   (2521, 1),
#   (2522, 1),
#   (2523, 4),
#   (2524, 1),
#   (2525, 16),
#   (2526, 1),
#   (2527, 2),
#   (2528, 1),
#   (2529, 1),
#   (2530, 1),
#   (2531, 4),
#   (2532, 1),
#   (2533, 3),
#   (2534, 2),
#   (2535, 1),
#   (2536, 6),
#   (2537, 3),
#   (2538, 1),
#   (2539, 2),
#   (2540, 1),
#   (2541, 3),
#   (2542, 6),
#   (2543, 1),
#   (2544, 1),
#   (2545, 1),
#   (2546, 1),
#   (2547, 1),
#   (2548, 4),
#   (2549, 1),
#   (2550, 1),
#   (2551, 2),
#   (2552, 1),
#   (2553, 1),
#   (2554, 4),
#   (2555, 3),
#   (2556, 1),
#   (2557, 7),
#   (2558, 1),
#   (2559, 3),
#   (2560, 1),
#   (2561, 1),
#   (2562, 1),
#   (2563, 2),
#   (2564, 23),
#   (2565, 1),
#   (2566, 1),
#   (2567, 3),
#   (2568, 1),
#   (2569, 1),
#   (2570, 1),
#   (2571, 5),
#   (2572, 1),
#   (2573, 1),
#   (2574, 1),
#   (2575, 2),
#   (2576, 1),
#   (2577, 2),
#   (2578, 1),
#   (2579, 1),
#   (2580, 1),
#   (2581, 4),
#   (2582, 1),
#   (2583, 1),
#   (2584, 1),
#   (2585, 1),
#   (2586, 1),
#   (2587, 1),
#   (2588, 2),
#   (2589, 3),
#   (2590, 1),
#   (2591, 1),
#   (2592, 4),
#   (2593, 2),
#   (2594, 2),
#   (2595, 1),
#   (2596, 1),
#   (2597, 2),
#   (2598, 2),
#   (2599, 1),
#   (2600, 2),
#   (2601, 3),
#   (2602, 1),
#   (2603, 5),
#   (2604, 3),
#   (2605, 3),
#   (2606, 1),
#   (2607, 1),
#   (2608, 2),
#   (2609, 1),
#   (2610, 1),
#   (2611, 1),
#   (2612, 1),
#   (2613, 1),
#   (2614, 1),
#   (2615, 13),
#   (2616, 1),
#   (2617, 1),
#   (2618, 1),
#   (2619, 2),
#   (2620, 1),
#   (2621, 1),
#   (2622, 2),
#   (2623, 1),
#   (2624, 6),
#   (2625, 5),
#   (2626, 1),
#   (2627, 1),
#   (2628, 2),
#   (2629, 1),
#   (2630, 2),
#   (2631, 1),
#   (2632, 1),
#   (2633, 1),
#   (2634, 1),
#   (2635, 1),
#   (2636, 1),
#   (2637, 1),
#   (2638, 1),
#   (2639, 1),
#   (2640, 1),
#   (2641, 1),
#   (2642, 1),
#   (2643, 1),
#   (2644, 2),
#   (2645, 1),
#   (2646, 2),
#   (2647, 1),
#   (2648, 1),
#   (2649, 4),
#   (2650, 11),
#   (2651, 4),
#   (2652, 2),
#   (2653, 1),
#   (2654, 1),
#   (2655, 1),
#   (2656, 1),
#   (2657, 5),
#   (2658, 1),
#   (2659, 2),
#   (2660, 5),
#   (2661, 4),
#   (2662, 2),
#   (2663, 1),
#   (2664, 1),
#   (2665, 1),
#   (2666, 1),
#   (2667, 1),
#   (2668, 1),
#   (2669, 5),
#   (2670, 5),
#   (2671, 1),
#   (2672, 1),
#   (2673, 1),
#   (2674, 1),
#   (2675, 1),
#   (2676, 1),
#   (2677, 17),
#   (2678, 1),
#   (2679, 2),
#   (2680, 4),
#   (2681, 1),
#   (2682, 3),
#   (2683, 1),
#   (2684, 4),
#   (2685, 1),
#   (2686, 1),
#   (2687, 1),
#   (2688, 1),
#   (2689, 1),
#   (2690, 1),
#   (2691, 1),
#   (2692, 1),
#   (2693, 4),
#   (2694, 3),
#   (2695, 1),
#   (2696, 3),
#   (2697, 1),
#   (2698, 1),
#   (2699, 6),
#   (2700, 2),
#   (2701, 1),
#   (2702, 3),
#   (2703, 2),
#   (2704, 2),
#   (2705, 1),
#   (2706, 9),
#   (2707, 1),
#   (2708, 1),
#   (2709, 1),
#   (2710, 1),
#   (2711, 1),
#   (2712, 1),
#   (2713, 2),
#   (2714, 1),
#   (2715, 1),
#   (2716, 1),
#   (2717, 1),
#   (2718, 1),
#   (2719, 1),
#   (2720, 1),
#   (2721, 1),
#   (2722, 2),
#   (2723, 2),
#   (2724, 1),
#   (2725, 2),
#   (2726, 2),
#   (2727, 1),
#   (2728, 28),
#   (2729, 4),
#   (2730, 2),
#   (2731, 1),
#   (2732, 6),
#   (2733, 9),
#   (2734, 2),
#   (2735, 11),
#   (2736, 2),
#   (2737, 33),
#   (2738, 1),
#   (2739, 7),
#   (2740, 116),
#   (2741, 5),
#   (2742, 1),
#   (2743, 3),
#   (2744, 1),
#   (2745, 1),
#   (2746, 2),
#   (2747, 1),
#   (2748, 1),
#   (2749, 4),
#   (2750, 1),
#   (2751, 1),
#   (2752, 2),
#   (2753, 1),
#   (2754, 2),
#   (2755, 1),
#   (2756, 8),
#   (2757, 1),
#   (2758, 3),
#   (2759, 5),
#   (2760, 31),
#   (2761, 1),
#   (2762, 3),
#   (2763, 1),
#   (2764, 1),
#   (2765, 1),
#   (2766, 1),
#   (2767, 1),
#   (2768, 2),
#   (2769, 1),
#   (2770, 1),
#   (2771, 1),
#   (2772, 1),
#   (2773, 1),
#   (2774, 1),
#   (2775, 3),
#   (2776, 1),
#   (2777, 4),
#   (2778, 1),
#   (2779, 1),
#   (2780, 5),
#   (2781, 5),
#   (2782, 2),
#   (2783, 4),
#   (2784, 1),
#   (2785, 7),
#   (2786, 4),
#   (2787, 1),
#   (2788, 1),
#   (2789, 1),
#   (2790, 4),
#   (2791, 8),
#   (2792, 1),
#   (2793, 4),
#   (2794, 1),
#   (2795, 1),
#   (2796, 1),
#   (2797, 3),
#   (2798, 2),
#   (2799, 2),
#   (2800, 1),
#   (2801, 1),
#   (2802, 62),
#   (2803, 1),
#   (2804, 1),
#   (2805, 1),
#   (2806, 1),
#   (2807, 1),
#   (2808, 1),
#   (2809, 1),
#   (2810, 9),
#   (2811, 4),
#   (2812, 1),
#   (2813, 3),
#   (2814, 2),
#   (2815, 2),
#   (2816, 1),
#   (2817, 1),
#   (2818, 3),
#   (2819, 1),
#   (2820, 1),
#   (2821, 1),
#   (2822, 1),
#   (2823, 2),
#   (2824, 12),
#   (2825, 1),
#   (2826, 1),
#   (2827, 1),
#   (2828, 1),
#   (2829, 1),
#   (2830, 1),
#   (2831, 1),
#   (2832, 1),
#   (2833, 5),
#   (2834, 4),
#   (2835, 1),
#   (2836, 1),
#   (2837, 4),
#   (2838, 1),
#   (2839, 1),
#   (2840, 2),
#   (2841, 3),
#   (2842, 1),
#   (2843, 1),
#   (2844, 1),
#   (2845, 1),
#   (2846, 1),
#   (2847, 1),
#   (2848, 1),
#   (2849, 1),
#   (2850, 1),
#   (2851, 1),
#   (2852, 1),
#   (2853, 1),
#   (2854, 1),
#   (2855, 4),
#   (2856, 1),
#   (2857, 2),
#   (2858, 1),
#   (2859, 1),
#   (2860, 1),
#   (2861, 1),
#   (2862, 4),
#   (2863, 1),
#   (2864, 1),
#   (2865, 2),
#   (2866, 1),
#   (2867, 1),
#   (2868, 1),
#   (2869, 1),
#   (2870, 1),
#   (2871, 2),
#   (2872, 3),
#   (2873, 1),
#   (2874, 1),
#   (2875, 1),
#   (2876, 1),
#   (2877, 2),
#   (2878, 2),
#   (2879, 5),
#   (2880, 1),
#   (2881, 2),
#   (2882, 1),
#   (2883, 11),
#   (2884, 1),
#   (2885, 1),
#   (2886, 1),
#   (2887, 1),
#   (2888, 1),
#   (2889, 1),
#   (2890, 2),
#   (2891, 6),
#   (2892, 1),
#   (2893, 4),
#   (2894, 1),
#   (2895, 3),
#   (2896, 1),
#   (2897, 1),
#   (2898, 1),
#   (2899, 3),
#   (2900, 2),
#   (2901, 1),
#   (2902, 1),
#   (2903, 2),
#   (2904, 2),
#   (2905, 1),
#   (2906, 9),
#   (2907, 2),
#   (2908, 2),
#   (2909, 8),
#   (2910, 1),
#   (2911, 8),
#   (2912, 2),
#   (2913, 3),
#   (2914, 2),
#   (2915, 1),
#   (2916, 8),
#   (2917, 8),
#   (2918, 7),
#   (2919, 1),
#   (2920, 1),
#   (2921, 1),
#   (2922, 2),
#   (2923, 1),
#   (2924, 1),
#   (2925, 3),
#   (2926, 1),
#   (2927, 1),
#   (2928, 1),
#   (2929, 1),
#   (2930, 1),
#   (2931, 1),
#   (2932, 1),
#   (2933, 2),
#   (2934, 7),
#   (2935, 2),
#   (2936, 1),
#   (2937, 1),
#   (2938, 2),
#   (2939, 1),
#   (2940, 2),
#   (2941, 1),
#   (2942, 1),
#   (2943, 1),
#   (2944, 2),
#   (2945, 1),
#   (2946, 1),
#   (2947, 1),
#   (2948, 1),
#   (2949, 1),
#   (2950, 1),
#   (2951, 1),
#   (2952, 1),
#   (2953, 1),
#   (2954, 1),
#   (2955, 1),
#   (2956, 6),
#   (2957, 1),
#   (2958, 1),
#   ...]]

# %%
lda=gensim.models.ldamodel.LdaModel(input_corpus,num_topics=4,id2word=input_dict,passes=50)

# %%
topics=lda.print_topics(num_words=20)
topics
# Out:
# [(0,
#   '0.019*"covid" + 0.010*"disease" + 0.007*"virus" + 0.007*"people" + 0.006*"may" + 0.006*"infection" + 0.006*"case" + 0.006*"health" + 0.006*"treatment" + 0.006*"ha" + 0.006*"sars" + 0.005*"cov" + 0.005*"symptom" + 0.005*"wa" + 0.005*"death" + 0.005*"also" + 0.005*"coronavirus" + 0.004*"respiratory" + 0.004*"severe" + 0.004*"patient"'),
#  (1,
#   '0.000*"ha" + 0.000*"wa" + 0.000*"covid" + 0.000*"data" + 0.000*"iit" + 0.000*"disease" + 0.000*"kharagpur" + 0.000*"institute" + 0.000*"doraemon" + 0.000*"technology" + 0.000*"people" + 0.000*"virus" + 0.000*"infection" + 0.000*"student" + 0.000*"science" + 0.000*"cov" + 0.000*"sars" + 0.000*"first" + 0.000*"research" + 0.000*"year"'),
#  (2,
#   '0.031*"doraemon" + 0.013*"series" + 0.011*"manga" + 0.010*"wa" + 0.008*"japanese" + 0.007*"ha" + 0.007*"nobita" + 0.007*"anime" + 0.006*"volume" + 0.006*"japan" + 0.006*"english" + 0.005*"film" + 0.005*"first" + 0.005*"child" + 0.005*"also" + 0.005*"shogakukan" + 0.004*"published" + 0.004*"version" + 0.004*"million" + 0.004*"character"'),
#  (3,
#   '0.015*"iit" + 0.014*"kharagpur" + 0.014*"student" + 0.013*"data" + 0.012*"science" + 0.011*"institute" + 0.009*"technology" + 0.007*"ha" + 0.007*"hall" + 0.006*"school" + 0.006*"india" + 0.006*"engineering" + 0.005*"research" + 0.005*"wa" + 0.005*"year" + 0.004*"campus" + 0.004*"million" + 0.004*"course" + 0.003*"k" + 0.003*"programme"')]

# %%
for t in topics:
    print(t)
# Out:
# (0, '0.019*"covid" + 0.010*"disease" + 0.007*"virus" + 0.007*"people" + 0.006*"may" + 0.006*"infection" + 0.006*"case" + 0.006*"health" + 0.006*"treatment" + 0.006*"ha" + 0.006*"sars" + 0.005*"cov" + 0.005*"symptom" + 0.005*"wa" + 0.005*"death" + 0.005*"also" + 0.005*"coronavirus" + 0.004*"respiratory" + 0.004*"severe" + 0.004*"patient"')
# (1, '0.000*"ha" + 0.000*"wa" + 0.000*"covid" + 0.000*"data" + 0.000*"iit" + 0.000*"disease" + 0.000*"kharagpur" + 0.000*"institute" + 0.000*"doraemon" + 0.000*"technology" + 0.000*"people" + 0.000*"virus" + 0.000*"infection" + 0.000*"student" + 0.000*"science" + 0.000*"cov" + 0.000*"sars" + 0.000*"first" + 0.000*"research" + 0.000*"year"')
# (2, '0.031*"doraemon" + 0.013*"series" + 0.011*"manga" + 0.010*"wa" + 0.008*"japanese" + 0.007*"ha" + 0.007*"nobita" + 0.007*"anime" + 0.006*"volume" + 0.006*"japan" + 0.006*"english" + 0.005*"film" + 0.005*"first" + 0.005*"child" + 0.005*"also" + 0.005*"shogakukan" + 0.004*"published" + 0.004*"version" + 0.004*"million" + 0.004*"character"')
# (3, '0.015*"iit" + 0.014*"kharagpur" + 0.014*"student" + 0.013*"data" + 0.012*"science" + 0.011*"institute" + 0.009*"technology" + 0.007*"ha" + 0.007*"hall" + 0.006*"school" + 0.006*"india" + 0.006*"engineering" + 0.005*"research" + 0.005*"wa" + 0.005*"year" + 0.004*"campus" + 0.004*"million" + 0.004*"course" + 0.003*"k" + 0.003*"programme"')
